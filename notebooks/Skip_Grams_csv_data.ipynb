# %% [markdown]
# # colab setup

# %%
# !pip install pip install git+https://github.com/ahmedbadr97/train-tracker
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/ahmedbadr97/train-tracker
#   Cloning https://github.com/ahmedbadr97/train-tracker to /tmp/pip-req-build-q8bm269y
#   Running command git clone -q https://github.com/ahmedbadr97/train-tracker /tmp/pip-req-build-q8bm269y
# Requirement already satisfied: pip in /usr/local/lib/python3.8/dist-packages (21.1.3)
# Collecting install
#   Downloading install-1.3.5-py3-none-any.whl (3.2 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from train-tracker==0.0.1) (1.12.1+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from train-tracker==0.0.1) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from train-tracker==0.0.1) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->train-tracker==0.0.1) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->train-tracker==0.0.1) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->train-tracker==0.0.1) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch->train-tracker==0.0.1) (4.1.1)
# Building wheels for collected packages: train-tracker
#   Building wheel for train-tracker (setup.py) ... done
#   Created wheel for train-tracker: filename=train_tracker-0.0.1-py3-none-any.whl size=7744 sha256=908a2a27ddcc00bb2d61a829d80749aee06d9f980142ac89a4d19d42e9a01a3f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mfwci1y2/wheels/c0/62/5e/0351c11b3e5b24a5a6235943ff962a6a00e510e2391699df53
# Successfully built train-tracker
# Installing collected packages: train-tracker, install
# Successfully installed install-1.3.5 train-tracker-0.0.1

# %%
# !git clone https://github.com/ahmedbadr97/sentiment-analysis-RNN
# Out:
# Cloning into 'sentiment-analysis-RNN'...
# remote: Enumerating objects: 171, done.
# remote: Counting objects: 100% (171/171), done.
# remote: Compressing objects: 100% (121/121), done.
# remote: Total 171 (delta 84), reused 132 (delta 45), pack-reused 0
# Receiving objects: 100% (171/171), 1.03 MiB | 11.77 MiB/s, done.
# Resolving deltas: 100% (84/84), done.

# %%
import config
#- config data --> git_username, email ,git_token, repository_name, kaggle_username, kaggle_key 
# !git config --global user.name {config.git_username}
# !git config --global user.email {config.email}
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-fd22aebe82bf> in <module>
# ----> 1 import config
#       2 #- config data --> git_username, email ,git_token, repository_name, kaggle_username, kaggle_key
#       3 get_ipython().system('git config --global user.name {config.git_username}')
#       4 get_ipython().system('git config --global user.email {config.email}')
#
# ModuleNotFoundError: No module named 'config'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !git remote remove origin

# !git remote add origin https://github.com/ahmedbadr97/sentiment-analysis-RNN

# %%
# !git pull origin main --force
# Out:
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 11 (delta 8), reused 8 (delta 5), pack-reused 0
# Unpacking objects: 100% (11/11), done.
# From https://github.com/ahmedbadr97/sentiment-analysis-RNN
#  * branch            main       -> FETCH_HEAD
#    7104443..c3935a6  main       -> origin/main
# Updating 7104443..c3935a6
# Fast-forward
#  notebooks/Skip_Grams.ipynb | 10 +++++-----
#  src/dataloader.py          | 27 +++++++++++++++++----------
#  src/model_training.py      |  2 ++
#  3 files changed, 24 insertions(+), 15 deletions(-)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/skipgram.zip -d /content/drive/MyDrive/projects/
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/skipgram.zip, /content/drive/MyDrive/skipgram.zip.zip or /content/drive/MyDrive/skipgram.zip.ZIP.

# %%
# !zip -r /content/drive/MyDrive/skipgram.zip /content/drive/MyDrive/projects/sentiment-analysis-RNN

# %%
# !pip install gdown

# %%
import gdown

# %%
url="https://storage.googleapis.com/kaggle-data-sets/1875905/3063858/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20221202%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20221202T124244Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..."
gdown.download(url,'/content/dataset.zip')
# Out:
# Downloading...
# From: https://storage.googleapis.com/kaggle-data-sets/1875905/3063858/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20221202%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20221202T124244Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# To: /content/dataset.zip
# 100%|██████████| 21.6M/21.6M [00:00<00:00, 95.5MB/s]
# '/content/dataset.zip'

# %%
# !unzip /content/dataset.zip -d {raw_dataset_dir}
# Out:
# Archive:  /content/dataset.zip
#   inflating: /content/drive/MyDrive/projects/sentiment-analysis-RNN/dataset/raw/movie.csv

# %%
# %cd /content/sentiment-analysis-RNN
# Out:
# /content/sentiment-analysis-RNN

# %%
# Define Constants and imports
import os
from collections import Counter
import matplotlib.pyplot as plt
import pandas as pd
from string import punctuation
import src
from importlib import reload
import traintracker

reload(src)

raw_dataset_dir = "../dataset/raw"
prep_dataset_dir = "../dataset/preprocessed"

weights_dir="../model_weights/skipgram"
train_tracker_path="../train_tracker"

train_data_dir="../train_tracker"

# %% [markdown]
# # Introduction
# In this notebook, I'll  implement the [Word2Vec algorithm](https://en.wikipedia.org/wiki/Word2vec) using the skip-gram architecture as a starter step for sentiment analysis creating first the words embeddings then use these embeddings for sentiment analysis

# %% [markdown]
# # Data Loading
# - load and view the reviews dataset

# %%
os.listdir(raw_dataset_dir)
# Out:
# ['labels.txt', 'reviews.txt', 'text8']

# %%
reviews_df=pd.read_csv(os.path.join(raw_dataset_dir,'movie.csv'))
reviews_df.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 reviews_df=pd.read_csv(os.path.join(raw_dataset_dir,'movie.csv'))
#       2 reviews_df.info()
#
# File C:\graduation_project\efficient-facenet\venv\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\graduation_project\efficient-facenet\venv\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File C:\graduation_project\efficient-facenet\venv\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File C:\graduation_project\efficient-facenet\venv\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File C:\graduation_project\efficient-facenet\venv\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File C:\graduation_project\efficient-facenet\venv\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../dataset/raw\\movie.csv'

# %%
reviews_df.groupby(by='label').count()
# Out:
#         text
# label
# 0      20019
# 1      19981

# %%
reviews_df.head()

# %%
print(reviews_df.iloc[0][0])
print(reviews_df.iloc[0][1])

# %%
# - change the reviews to one txt seprated by `\n` newline character
reviews_list=[]
labels_list=[]
size=len(reviews_df)
for i in range(size):
  reviews_list.append(reviews_df.iloc[i][0])
  
  labels_list.append("positive"  if reviews_df.iloc[i][1]==1 else "negative")
  if i<size-1:
    reviews_list.append('\n')
    labels_list.append('\n')

# %%
raw_reviews_txt="".join(reviews_list)
raw_labels_txt="".join(labels_list)
print(len(raw_reviews_txt.split('\n')))
# Out:
# 40000

# %%
# saving labels to txt file
with open(os.path.join(prep_dataset_dir, "labels.txt"), 'w') as leables_file:
    leables_file.write(raw_labels_txt)

# %% [markdown]
# - reviews are line separated and the reviews also

# %% [markdown]
# ## view words freqencies
# - show word freqencies before any preprocessing

# %%
words_counter = Counter(raw_reviews_txt.split())

# %%
words_df = pd.DataFrame(words_counter.items(), columns=['word', 'count'])
words_df.sort_values(by=['count'], ascending=False, inplace=True)
print(f"no of unique words={len(words_df)}\nno of words ={words_df['count'].sum()}")
# Out:
# no of unique words=381542
# no of words =9253570

# %%
# get 50 from top , mid and end
src.data_preprocessing.get_head_mid_tail(words_df,50)
# Out:
#                   word   count
# 8                  the  455003
# 51                   a  246023
# 6                  and  242041
# 53                  of  226965
# 27                  to  209659
# ...                ...     ...
# 198462  policewoman's,       1
# 198464         Palusky       1
# 198465           Kayle       1
# 198466         Timler,       1
# 381541         "Chains       1
#
# [150 rows x 2 columns]

# %%
words_df.describe()
# Out:
#                count
# count  381542.000000
# mean       24.253084
# std      1240.617558
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         3.000000
# max    455003.000000

# %% [markdown]
# - high standard deviation due the usage of words like 'the' and using punctuations in words make them counted as diffrent words
# - 75% of the words count smaller than 3
# - about 50% words appear once , may be misspelled words

# %%
words_df.median()
# Out:
# <ipython-input-18-0af9609fa379>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   words_df.median()
# count    1.0
# dtype: float64

# %% [markdown]
# - a words with count =1 appear from the midean to the end due to existance of punctations and the txt exist in thier lower and upper case

# %% [markdown]
# # Data preprocessing
# - remove punctuations , set all chars to lowercase
# - remove noise words that appear once , that might be misspelling
# - remove high frequent words that doesn't add thing to the neighboring word
# - save the preprocessed data

# %% [markdown]
# **probability of word removal**
# - Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations.
# - This process is called subsampling by Mikolov.For each word wi) in the training set,
# - we'll discard it with probability given by
# - ![p_remove1.png](./assets/p_remove1.png)![p_remove2.png](./assets/p_remove2.png)
# - p--> probability of discarding word
# - t--> threshold of word count that the probability of discarding will begin to increase from `T/t`
# - f--> frequency of a word
# - T--> total number of words
# - `set t=100 and T=500000=1e5 ` probability of removal will start to be grater than zero when the f=5000
# - ![p_remove_curve.png]((./assets/p_remove_curve.png)

# %% [markdown]
# ## remove invalid chars

# %%
prep_txt = src.remove_punctuations(raw_reviews_txt)

# %%
words_counter = Counter(prep_txt.split())

words_df = pd.DataFrame(words_counter.items(), columns=['word', 'count'])
words_df.sort_values(by=['count'], ascending=False, inplace=True)
print(f"no of unique words={len(words_df)}\nno of words ={words_df['count'].sum()}")
# Out:
# no of unique words=160310
# no of words =9217166

# %% [markdown]
# no of unique words decreased from `381542`  to `160310` because we removed punctuation characters so word like `The. ` and `the?` will be `the` and will be counted as one word

# %%
def cnt_ranges(df,step,col_name):
  size=len(df)
  df=df.sort_values(by=col_name)
  col_idx=df.columns.get_loc(col_name)

  ranges_list=[]
  smaller_value=0
  bigger_value=step

  df_idx=0
  while(df_idx<size):
    cnt=0
    while(df_idx<size and df.iloc[df_idx,col_idx]<=bigger_value):
      cnt+=1
      df_idx+=1
    if cnt>0:
      ranges_list.append([f"{smaller_value} to {bigger_value}",cnt])
    smaller_value+=step
    bigger_value+=step
  return ranges_list

# %%
r=cnt_ranges(words_df,20,'count')

# %%
pd.DataFrame(r,columns=["range",'cnt'])
# Out:
#                 range     cnt
# 0             0 to 20  142824
# 1            20 to 40    6260
# 2            40 to 60    2771
# 3            60 to 80    1526
# 4           80 to 100    1059
# ..                ...     ...
# 397  213640 to 213660       1
# 398  230740 to 230760       1
# 399  256820 to 256840       1
# 400  256900 to 256920       1
# 401  531180 to 531200       1
#
# [402 rows x 2 columns]

# %%
src.get_head_mid_tail(words_df,100)
# Out:
#                         word   count
# 8                        the  531191
# 6                        and  256916
# 47                         a  256838
# 49                        of  230759
# 23                        to  213654
# ...                      ...     ...
# 90777           pointyfinger       1
# 90776      handymancarpenter       1
# 90775              paragonbr       1
# 90774   signorelliscreenplay       1
# 160309           fishermenbr       1
#
# [300 rows x 2 columns]

# %% [markdown]
# ##  word importance by pos/neg apperance ratio

# %%
words_pos_neg_ratio = src.get_word_importance(prep_txt, labels=raw_labels_txt)
                                                                           
min_val,max_val=0,-1

for word,ratio in words_pos_neg_ratio.items():
    min_val=min(ratio,min_val)
    max_val=max(ratio,max_val)
print(f"min_val {min_val}")
print(f"max_val {max_val}")
# Out:
# min_val -4.127134385045092
# max_val 4.727387818712341

# %%
raw_reviews_txt[:1000]
# Out:
# 'I grew up (b. 1965) watching and loving the Thunderbirds. All my mates at school watched. We played "Thunderbirds" before school, during lunch and after school. We all wanted to be Virgil or Scott. No one wanted to be Alan. Counting down from 5 became an art form. I took my children to see the movie hoping they would get a glimpse of what I loved as a child. How bitterly disappointing. The only high point was the snappy theme tune. Not that it could compare with the original score of the Thunderbirds. Thankfully early Saturday mornings one television channel still plays reruns of the series Gerry Anderson and his wife created. Jonatha Frakes should hand in his directors chair, his version was completely hopeless. A waste of film. Utter rubbish. A CGI remake may be acceptable but replacing marionettes with Homo sapiens subsp. sapiens was a huge error of judgment.\nWhen I put this movie in my DVD player, and sat down with a coke and some chips, I had some expectations. I was hoping that t'

# %%
prep_txt[:1000]
# Out:
# 'i grew up b 1965 watching and loving the thunderbirds all my mates at school watched we played thunderbirds before school during lunch and after school we all wanted to be virgil or scott no one wanted to be alan counting down from 5 became an art form i took my children to see the movie hoping they would get a glimpse of what i loved as a child how bitterly disappointing the only high point was the snappy theme tune not that it could compare with the original score of the thunderbirds thankfully early saturday mornings one television channel still plays reruns of the series gerry anderson and his wife created jonatha frakes should hand in his directors chair his version was completely hopeless a waste of film utter rubbish a cgi remake may be acceptable but replacing marionettes with homo sapiens subsp sapiens was a huge error of judgment \n when i put this movie in my dvd player and sat down with a coke and some chips i had some expectations i was hoping that this movie would contain '

# %%
words_p_n_ratio_df=pd.DataFrame(words_pos_neg_ratio.items(),columns=['word','ratio']).sort_values(by=['ratio'])

# %%
words_p_n_ratio_df.describe()
# Out:
#                ratio
# count  161193.000000
# mean        0.048999
# std         0.818501
# min        -4.127134
# 25%        -0.693147
# 50%         0.000000
# 75%         0.693147
# max         4.727388

# %% [markdown]
# **Deciding the Ratio for noise**

# %%
print("common words")
print(f"pos and negative ratio for 'the' {words_pos_neg_ratio['those']}")
print(f"pos and negative ratio for 'him' {words_pos_neg_ratio['him']}")
print(f"pos and negative ratio for 'her' {words_pos_neg_ratio['her']}")
print(f"pos and negative ratio for 'is' {words_pos_neg_ratio['is']}")
print(f"pos and negative ratio for 'they' {words_pos_neg_ratio['they']}")
print(f"pos and negative ratio for 'did' {words_pos_neg_ratio['did']}")
print(f"pos and negative ratio for 'as' {words_pos_neg_ratio['as']}")
print(f"pos and negative ratio for 'a' {words_pos_neg_ratio['a']}")
print("\nPostive words")

print(f"pos and negative ratio for 'wonderful' {words_pos_neg_ratio['wonderful']}")
print(f"pos and negative ratio for 'amazing' {words_pos_neg_ratio['amazing']}")
print(f"pos and negative ratio for 'good' {words_pos_neg_ratio['good']}")
print(f"pos and negative ratio for 'excellent' {words_pos_neg_ratio['excellent']}")

print("\nnegative words")
print(f"pos and negative ratio for 'bad' {words_pos_neg_ratio['bad']}")
print(f"pos and negative ratio for 'worse' {words_pos_neg_ratio['worse']}")
print(f"pos and negative ratio for 'boring' {words_pos_neg_ratio['boring']}")
# Out:
# common words
# pos and negative ratio for 'the' 0.15040138861478275
# pos and negative ratio for 'him' 0.23241749635693773
# pos and negative ratio for 'her' 0.24583923387574738
# pos and negative ratio for 'is' 0.12302609115914889
# pos and negative ratio for 'they' -0.2687558382621351
# pos and negative ratio for 'did' -0.2160042141353108
# pos and negative ratio for 'as' 0.23724039177675732
# pos and negative ratio for 'a' 0.037063342877560294
#
# Postive words
# pos and negative ratio for 'wonderful' 1.5571694838883434
# pos and negative ratio for 'amazing' 1.343095156017315
# pos and negative ratio for 'good' 0.005656862045491339
# pos and negative ratio for 'excellent' 1.4842294169777621
#
# negative words
# pos and negative ratio for 'bad' -1.362353199221966
# pos and negative ratio for 'worse' -1.6799782168127269
# pos and negative ratio for 'boring' -1.5131861129745143

# %%
ratio_threshold=0.27
is_common_word=(words_p_n_ratio_df['ratio']>-ratio_threshold)&(words_p_n_ratio_df['ratio']<ratio_threshold)
is_positive_word=(words_p_n_ratio_df['ratio']>ratio_threshold)
is_negative_word=(words_p_n_ratio_df['ratio']<-ratio_threshold)


common_words=words_p_n_ratio_df[is_common_word].sort_values(by='ratio')

positive_words=words_p_n_ratio_df[is_positive_word].sort_values(by='ratio')

negative_words=words_p_n_ratio_df[is_negative_word].sort_values(by='ratio')

# %%
print("common words ",common_words['word'].count())
print("positive words ",positive_words['word'].count())
print("negative words ",negative_words['word'].count())
# Out:
# common words  18124
# positive words  75654
# negative words  67415

# %%
n_words=300
common_words_range=src.get_head_mid_tail(common_words,n_words)
positive_words_range=src.get_head_mid_tail(positive_words,n_words)
negative_words_range=src.get_head_mid_tail(negative_words,n_words)

display(common_words_range)
# Out:
#           word     ratio
# 3101      foot -0.269664
# 813     filthy -0.269664
# 45       would -0.269380
# 5529    bright -0.269255
# 2076      hide -0.269129
# ...        ...       ...
# 18671   downey  0.269664
# 19720     1986  0.269664
# 1528      told  0.269740
# 369    certain  0.269763
# 2939     entry  0.269824
#
# [900 rows x 2 columns]

# %%
# add exceptional words
excep=['story','movie','good','film','movies']
for word in excep:
  words_pos_neg_ratio[word]=1

# %% [markdown]
# ## remove word with hight freq and low freq

# %%
import src.data_preprocessing as prep
reload(prep)
# Out:
# <module 'src.data_preprocessing' from '/content/sentiment-analysis-RNN/src/data_preprocessing.py'>

# %%
filtered_prep_txt, noise_words,prob_drop_dist = prep.remove_noise(prep_txt, p_drop_dist_threshold=1e4, min_prob_drop=0.8, min_freq=20,min_rev_freq=5,common_words_threshold=0.27,word_importance_dict=words_pos_neg_ratio)

# %%
prob_drop_word_df=pd.DataFrame(prob_drop_dist.items(),columns=["word",'probabilty of drop']).sort_values(by=['probabilty of drop'],ascending=False)

# %%
prob_drop_word_df.head(150)
# Out:
#              word  probabilty of drop
# 8             the            0.958344
# 6             and            0.940103
# 47              a            0.940094
# 49             of            0.936800
# 23             to            0.934318
# ...           ...                 ...
# 600          must            0.565623
# 1971        times            0.564955
# 470   interesting            0.563383
# 137        comedy            0.561931
# 390          done            0.559076
#
# [150 rows x 2 columns]

# %%
noise_words
# Out:
# ['replanted',
#  '£5oo',
#  'plotsso',
#  'joydeep',
#  'musseum',
#  'gargon',
#  'rebe',
#  'phantasmagorical',
#  'preferisco',
#  'retaking',
#  'talpiot',
#  'seinfeldafter',
#  'hosanna',
#  'surmounts',
#  'personalitymodern',
#  'killerwhereas',
#  'lightest',
#  'kush',
#  'trippers',
#  'gametomovie',
#  'chairwoman',
#  'nopd',
#  'toleration',
#  'newagey',
#  'eroticabr',
#  'viciente',
#  'expertonce',
#  'unpharoh',
#  'aoh',
#  'gentrified',
#  'twop',
#  'selfreflexivity',
#  'suspectdenniss',
#  'rietty',
#  'middleweight',
#  'ce3k',
#  'ambushers',
#  'allthough',
#  'talladega',
#  'diary43',
#  'joshuu',
#  'chicagoset',
#  'pising',
#  'treasureshickey',
#  'batlike',
#  'dillonbr',
#  'screenplaydirecting',
#  'silkk',
#  'peruses',
#  'entrée',
#  'soraia',
#  'livefoes',
#  'nonclassicbr',
#  'appropriatebut',
#  'notknowing',
#  'dajani',
#  'twogallons',
#  'smolley',
#  'carnbybr',
#  'fuir',
#  'astaire’s',
#  'openedhe',
#  'holstering',
#  'capecloak',
#  'factsthe',
#  'muto',
#  '11001001',
#  'justoutofprison',
#  'areweird',
#  'brownsuch',
#  'storycharactersatmosphere',
#  'torturer',
#  'dorado',
#  'lyingin',
#  'canuckteach',
#  'antithetical',
#  'puzzlingly',
#  'mwuhahahaa',
#  'notsomainstream',
#  'blackmaillost',
#  'loudim',
#  'backcountry',
#  'happing',
#  'conestoga',
#  'scarey',
#  'filmaustraliabr',
#  'oddunusual',
#  'thisback',
#  'wendersbr',
#  'subaudible',
#  'feidel',
#  'chilman',
#  'saferbr',
#  'vaunted',
#  'ruinbr',
#  'flavorwhich',
#  'alignedbr',
#  'naziprison',
#  'bucketful',
#  'shopsbr',
#  'brodsk',
#  'sceneryit',
#  'depardieunaturally',
#  'ywca',
#  'praythe',
#  'krimis',
#  'ariette',
#  'warand',
#  'sfblockbuster',
#  'airlinerindistress',
#  'ninnieshas',
#  'tvmoviesmadetoorder',
#  'givea',
#  'voightmidnight',
#  'you´r',
#  'subtitletagline',
#  'cazenovethe',
#  'dealthe',
#  'bouccymarie',
#  'spradlin',
#  'libbys',
#  'filmette',
#  'hygienist',
#  'goodatheart',
#  'idealisticbr',
#  'ironyfreighted',
#  'reviewerbr',
#  'spidermanor',
#  'pupwho',
#  'falsetto',
#  'suicideto',
#  'slavestates',
#  'leastthe',
#  'moni',
#  'efx',
#  'starwithapart',
#  'imthefigurativeandliteralrepresentationofthenakedvulnerabilityof',
#  'incriminate',
#  'ferried',
#  'chinathe',
#  'wanedbr',
#  'agusti',
#  'realisticthe',
#  'compensations',
#  'ottoman',
#  'vampiredemons',
#  'muh',
#  'almodavar',
#  'kindnessbr',
#  'charm9is',
#  'trudeau',
#  'killin',
#  'appriciate',
#  'faber',
#  'celaschi',
#  'str8',
#  'repentant',
#  'iñárritus',
#  'hiroyuki',
#  'clackityclacks',
#  'c1850',
#  'algerian',
#  'segmentseach',
#  '3part',
#  'ricki',
#  'gialloand',
#  'hig',
#  'outeraesthetic',
#  'managerthe',
#  'jumper',
#  'cypherbr',
#  'iqbr',
#  'macneil',
#  'cityand',
#  'segregationintegration',
#  'tenthgeneration',
#  'aspectbr',
#  'newish',
#  'personal\x97as',
#  'allive',
#  'readywhip',
#  'toooften',
#  'economist',
#  'flys',
#  'sixtiesmeryl',
#  'agreepure',
#  'showtim',
#  'annmaries',
#  'filmsequences',
#  'disgorged',
#  'refinery',
#  'caulder',
#  'brodiebr',
#  'richardbut',
#  'vinod',
#  'likablewell',
#  'oneotherwise',
#  'sensai',
#  'brazils',
#  'wildman',
#  'blogging',
#  'gianta',
#  'boyfriendfiancée',
#  '416',
#  'brutti',
#  'ohsodaring',
#  'casss',
#  'counterclaims',
#  'benedictthe',
#  'snapebr',
#  'unwholesome',
#  'mensexlust',
#  'pointyfinger',
#  'subterfugehow',
#  'ulagam',
#  'moustached',
#  'lesleyann',
#  'pervertedand',
#  'anyyou',
#  'kindone',
#  'axle',
#  'hisyuki',
#  'allhow',
#  'vietnamthe',
#  'joyfulness',
#  '4and',
#  'lunching',
#  'littledevilontheshoulder',
#  'plagiarizing',
#  'toeing',
#  'temujin',
#  'momentsit',
#  'morethe',
#  'isntoccurrencesbr',
#  'charelston',
#  'guiltunfortunatelythe',
#  'repute',
#  'panza',
#  'nether',
#  'kzguantanamo',
#  'defences',
#  'pulloutallthestops',
#  'portaraying',
#  'mayans',
#  'soderburg',
#  'sarandonwho',
#  'straightthis',
#  'disected',
#  'spatbr',
#  '19311997br',
#  'gunghotrigger',
#  'lob',
#  'yentlbr',
#  '£250000',
#  'eventfully',
#  'songsyou',
#  'federlineokay',
#  'subtracts',
#  'kryukova',
#  '51ch',
#  'singeractress',
#  'beautifulpoetic',
#  'mylod',
#  'reidelsheimers',
#  'splendors',
#  'katell',
#  'bilbo',
#  'roopa',
#  'jestermasked',
#  '18602',
#  'infraredlike',
#  'kersy',
#  'parables',
#  'birdsthe',
#  'attendbr',
#  'reallyive',
#  '£7',
#  'ofourse',
#  'noveli',
#  'bowdens',
#  'rivetting',
#  'mcvicar',
#  'xtasy',
#  'uselessit',
#  'currentevent',
#  'gavras',
#  'misguide',
#  'afb',
#  'mooreland',
#  'replying',
#  'jumbobr',
#  'sijan',
#  'burgialien',
#  'bfeature',
#  'everpopular',
#  'gumbas',
#  'lathe',
#  'cockandbull',
#  'bogglingbr',
#  'enchantingly',
#  'liquidthe',
#  'pleasuredenying',
#  'ademir',
#  'cameraonlyonbachchan',
#  'dengler',
#  'exterminationbr',
#  'dhia',
#  'uglyuncanonicalidioticand',
#  'bucketfulls',
#  'surethe',
#  'laetitia',
#  'mandark',
#  'classing',
#  'didactically',
#  'importantgive',
#  'noncomics',
#  'banns',
#  'scenesyet',
#  'sequelwhy',
#  'twoonone',
#  'gulag',
#  'vouched',
#  'urf',
#  'liszt',
#  'ellendunaway',
#  'toobadtheystink',
#  'wakefields',
#  'homageparody',
#  'savahanna',
#  'wrackingly',
#  'lufts',
#  'cybernetic',
#  'milwaulkee',
#  'naturalismbr',
#  'piemaker',
#  'bioinvisibilation',
#  'ou812',
#  'computerpros',
#  'girlygirlno',
#  'clayanimated',
#  'olivetti',
#  'ingeborgs',
#  'goodingjr',
#  'chowno',
#  'poultry',
#  'doesn',
#  'sackvillebagginses',
#  'duracks',
#  'reorient',
#  'birell',
#  'spitefully',
#  'ricess',
#  'reboundbr',
#  'aerodynamic',
#  'pengiumsewer',
#  'hyperviolent',
#  'muddleheaded',
#  'lászló',
#  'versioncheck',
#  'krasnas',
#  'abusivehe',
#  'eagerlyawaited',
#  'musicit',
#  'mistakingly',
#  'crisping',
#  'wenchesbr',
#  'dalis',
#  'compellingyou',
#  '10dirgeorge',
#  'hpnxhotmailcom',
#  'nicodemus',
#  'hypnotising',
#  'innocente',
#  'hikers',
#  'lout',
#  'malldowntown',
#  'offnicholas',
#  'carmelageorge',
#  'godmotherbr',
#  'elys',
#  'ktel',
#  'manyim',
#  'mdixon',
#  'barlo',
#  'graceland',
#  'gubra',
#  'vandiver',
#  'pixies',
#  'hottub',
#  'landi',
#  'brune',
#  'ism',
#  'footageand',
#  'deservesremarkableand',
#  'taxman',
#  '1974era',
#  'unreported',
#  'zimmermann',
#  'costumy',
#  'chessiness',
#  'mwahahaha',
#  'wonderfullooking',
#  'lungren',
#  'hoeger',
#  'chappell',
#  'chatterleys',
#  'thoughprovoking',
#  '50thousand',
#  'fantatical',
#  'inferring',
#  'estimations',
#  'luchador',
#  'coolantantifreeze',
#  'minimoog',
#  'ayoadebr',
#  'speleologist',
#  'trojen',
#  'schwarzenegers',
#  'gingoldbr',
#  'ghostskulls',
#  'timeshifts',
#  'barband',
#  'directorcassie',
#  'etepetete',
#  'unconvincingscreaming',
#  'tijuana',
#  'tombas',
#  'mian',
#  'karatekick',
#  'deducts',
#  'biafra',
#  'verhoven',
#  'seashores',
#  'whored',
#  'lovability',
#  'viningbr',
#  'previewsbr',
#  'methadrinedexadrine',
#  'troopersronin',
#  'dacoit',
#  'warriorin',
#  'directionslooking',
#  'rachelscarlas',
#  'ymcasong',
#  'wardrobeeven',
#  'oscarawardwinning',
#  'africaans',
#  'cédrics',
#  'teenangst',
#  'dreufuss',
#  'quaversbr',
#  'gwangi',
#  'philosopherking',
#  'sigurðsson',
#  'graffitti',
#  'inhe',
#  'yasujiru',
#  'paxtonkimberly',
#  'khanalthough',
#  'stunnedbr',
#  'surein',
#  'hanley',
#  'reasondontthis',
#  'remixing',
#  'nwhere',
#  'vampirsim',
#  'predominated',
#  'rampantly',
#  'heisthostage',
#  'ubermorlock',
#  'thema',
#  'healera',
#  'mandelbaum',
#  'repeatsbr',
#  'studyone',
#  'highhanded',
#  'prioritizing',
#  'collorabr',
#  'bosco',
#  'oncracker',
#  'thousandtimesmade',
#  'neaglemichael',
#  'pervertedbr',
#  'falcãosbr',
#  'flashbackthe',
#  'psp',
#  'convenientsoldiers',
#  'curiousness',
#  'recapbaron',
#  'polack',
#  'blooddrenched',
#  'endtheseason',
#  'buffyangelbr',
#  'blockbr',
#  'fashionthe',
#  'malemale',
#  'jáaccuse',
#  'cgbr',
#  'callcentre',
#  'ocks',
#  'fashiongulp',
#  'purebredbr',
#  '209',
#  'authorcreator',
#  'unnattractivedistractingly',
#  'bipolarly',
#  'togetherinto',
#  'schirripa',
#  'transvestitekrista',
#  'melita',
#  'downplaying',
#  'ostern',
#  'bankrupted',
#  'scotties',
#  'longitude',
#  'spanishamerican',
#  'jameses',
#  'sharpwitted',
#  'planter',
#  'bloodyyou',
#  'protagonistbr',
#  'wilbert',
#  'ryanthis',
#  'muchthat',
#  'bably',
#  'disciplinarians',
#  'tryhighly',
#  'mongolia',
#  'shirô',
#  'nolls',
#  'jrdelroy',
#  'blixens',
#  'greatnot',
#  'penpal',
#  'patrician',
#  'rippling',
#  '102030',
#  'insightfulness',
#  'brunhild',
#  'trawlers',
#  'holderness',
#  'tardisbr',
#  'tiefenbachwillychris',
#  'instillation',
#  'pillbr',
#  'objectiveness',
#  'annoyedwonder',
#  'coursebut',
#  'allat',
#  'brotherchris',
#  'handwashed',
#  'londonesque',
#  'ménard',
#  'stagefor',
#  'gravesbr',
#  'godsend',
#  'fierceness',
#  'poundforpound',
#  'koichiro',
#  'loverviolatorbr',
#  'alldont',
#  'moviewhen',
#  'treebr',
#  'bathory',
#  'trailriders',
#  'mateand',
#  'reillys',
#  'scarierbr',
#  'outgrowing',
#  'scarfing',
#  'filmartsenglish',
#  'antieye',
#  'eventuate',
#  'investor',
#  'attentioneveryonehe',
#  'dominateing',
#  'swelter',
#  'tuxedoes',
#  'ves',
#  'camerashots',
#  'pendeltons',
#  '31339',
#  'aksar',
#  'guardboth',
#  'looniness',
#  'collapsedbr',
#  'riderdriver',
#  'nowadayscorrupt',
#  'cornybut',
#  'bosie',
#  'highspeed',
#  'ambushbr',
#  'badits',
#  'roomat',
#  'divinity',
#  'bidwell',
#  'moviedefinitely',
#  'onelight',
#  '112003',
#  'yoshitsune',
#  'plaekar',
#  'centerstage',
#  'latins',
#  'agnisakshi',
#  'ailmentnot',
#  'yaayyyyy',
#  'worldhow',
#  'joneswho',
#  'razdan',
#  'spidermaster',
#  'olden',
#  'dwarflittle',
#  'tichon',
#  'constrict',
#  'kasugi',
#  'ringleading',
#  'misappropriated',
#  'inveterate',
#  'gulliblebr',
#  'craponly',
#  'megans',
#  'yeastless',
#  'highlybudgeted',
#  'lemons',
#  'meoli',
#  'virzis',
#  'cloningcentral',
#  'tonnerre',
#  'bullt',
#  'hisaishis',
#  'religiosity',
#  'himperhaps',
#  'actingstreep',
#  'ashen',
#  'ashamebr',
#  'singerdancer',
#  'mft3k',
#  '2on',
#  '2in',
#  'kindsa',
#  'fung',
#  'vildan',
#  'walloping',
#  'liosa',
#  'vindicates',
#  'admittedlycolorful',
#  'anglophobes',
#  'pagemasterbr',
#  'kao',
#  'kindled',
#  'speerpet',
#  'stuntswhich',
#  'genova',
#  'punt',
#  'venalityyou',
#  'thedweebyengineers',
#  'ranvijay',
#  'kookpsychic',
#  'nomansland',
#  'tridev',
#  'christieninotchka39',
#  'dayan',
#  'elpidia',
#  '99¢',
#  'ctm',
#  'abercrombiefitch',
#  'recurrencebr',
#  'singleparent',
#  'conneryi',
#  'deftness',
#  'burnedout',
#  'ubersuave',
#  'quickfix',
#  'watchstander',
#  'geny',
#  'thameside',
#  'raggety',
#  'revengedrama',
#  'adevent',
#  'gainjin',
#  'peronism',
#  'pegbr',
#  'tirebr',
#  'nagged',
#  'barbituate',
#  'vietnampack',
#  'samhainbr',
#  'microlegs',
#  'proms',
#  'accustom',
#  'ebersole',
#  'battleweary',
#  'stintbr',
#  'ammityville',
#  'rodman',
#  'pathosbr',
#  'bihns',
#  'radiohead',
#  'interconnectivity',
#  'unreconstructed',
#  'cokefilled',
#  'angrezon',
#  'signifie',
#  'surgeonsperhaps',
#  'devourer',
#  'mahnaz',
#  'pratchett',
#  'evangelic',
#  'sayssince',
#  'fraudhe',
#  'horlicks',
#  'drteeth',
#  'shravan',
#  'braverygreatness',
#  'zigfield',
#  'screenfar',
#  'photoidea',
#  'chainwhipped',
#  'anybodyhe',
#  'handedbr',
#  'coinflipping',
#  'colisseum',
#  'yuria',
#  'havin',
#  'andrewss',
#  'schoolenglish',
#  'roosa',
#  'flannel',
#  'yipe',
#  'inverse',
#  'forsters',
#  'selfat',
#  'grupo',
#  'mongoloidbarbarians',
#  'bloodybr',
#  'poststalin',
#  'timesto',
#  'whittaker',
#  'claibourne',
#  'deathanyway',
#  'snafus',
#  'uninvested',
#  'cppy',
#  'beermat',
#  'testosteronebr',
#  'baretorsoed',
#  'moritamr',
#  'rejoicebr',
#  'edgehill',
#  'quiroz',
#  'poachers',
#  'jybr',
#  'explosiveness',
#  'laterim',
#  'sayprobably',
#  'baez',
#  'abortionist',
#  'snowstorm',
#  'panaceabr',
#  '1969the',
#  'superweapons',
#  'vandebrouck',
#  'forestier',
#  'composerbr',
#  'blackchurch',
#  'hustonanother',
#  'nonstopbr',
#  'medaks',
#  'posthypnotic',
#  'pretensionshidden',
#  'doubleexposures',
#  'slowerthe',
#  'effectsas',
#  'controlroom',
#  'ariadna',
#  'filmakingbr',
#  'boiing',
#  'couldnti',
#  'mitb',
#  'customizers',
#  'techheavy',
#  'pancamo',
#  'mcinness',
#  'riscorla',
#  'blackbeard',
#  'castouch',
#  'hotwho',
#  'yippiekeeyay',
#  'theretireddoctorfromthegovernment',
#  'sumishefali',
#  'publishes',
#  'russiankazakhalbanian',
#  'galholly',
#  'increadably',
#  'hovel',
#  'jarno',
#  '00agent',
#  'nowadaysat',
#  'robocops',
#  'menothingbr',
#  'palahniuks',
#  'threepack',
#  'disneywhen',
#  'sidious',
#  'vividlyif',
#  'lotand',
#  'comeons',
#  'striven',
#  'bannisterbr',
#  'pather',
#  'gandhijis',
#  'importantholmes',
#  'nataliabr',
#  'wirerope',
#  'nas',
#  'disapointment',
#  'sovs',
#  '1245am',
#  'fedor',
#  'partsbecause',
#  'enjolras',
#  'nimiwas',
#  'witherspoon\x96she',
#  'orndorff',
#  'goodlaughed',
#  'schoollevel',
#  'poetsbr',
#  'leopardclad',
#  'uganda',
#  'nesher',
#  'marthapauls',
#  'flackering',
#  'walesa',
#  'sleaziergoriernastier',
#  'schoolsanitized',
#  'typicalbr',
#  'minotaur',
#  'questionwhat',
#  'showwell',
#  'himselfthe',
#  'contrastbr',
#  '9100o',
#  'antagonized',
#  'crewhe',
#  'hardhammered',
#  'biasing',
#  'batra',
#  '4210',
#  'parentbr',
#  'listlessly',
#  'introd',
#  'nehru',
#  'decaune',
#  'clubor',
#  'archconservative',
#  'strangeworrying',
#  'castthats',
#  'valantines',
#  'armageddonbr',
#  'maybeand',
#  'songdances',
#  'blinken',
#  'serenading',
#  'tweedle',
#  'rioters',
#  'dragonsstyle',
#  'abondons',
#  'dryspell',
#  'formalism',
#  'dustbr',
#  '19401943',
#  'menerbes',
#  'helplesshuh',
#  'k20',
#  'writerdirectortechnical',
#  'maribel',
#  'progressbr',
#  'twobut',
#  'charactersbutyou',
#  'presumable',
#  'crapdombr',
#  'hehehello',
#  'ninetenths',
#  'trancestate',
#  'officerincharge',
#  'hitoshi',
#  'businessmenmillionares',
#  'mahoneys',
#  'outshining',
#  'cosplay',
#  'trekknockoff',
#  'phoneinsurancecola',
#  'definitaly',
#  'jejune',
#  'herin',
#  'litman',
#  'landybourne',
#  'florodora',
#  'saidno',
#  'mottocrossing',
#  'comatosealthough',
#  'hardcorehorror',
#  'prettified',
#  'matondkars',
#  '10of10',
#  'cokesnorting',
#  'mybr',
#  'bines',
#  'frommage',
#  'shotgunhappy',
#  'scaremongering',
#  'instilling',
#  'cheeker',
#  'overreactions',
#  'shivabr',
#  'armadillos',
#  'chasesfightsdirector',
#  'abdoo',
#  'plotif',
#  'andersonbr',
#  'rothbr',
#  'rudden',
#  'millius',
#  'thembananas',
#  'glovesbr',
#  'selfconscience',
#  'watchingsometimes',
#  'problemthe',
#  'unstuck',
#  'lagomorpha',
#  'shytbr',
#  'musicoriented',
#  'stuttgart',
#  'obstinacy',
#  'tedioussaying',
#  'chickswithdicks',
#  'mancusorichard',
#  'cameroons',
#  'holotiks',
#  'screwheads',
#  'bulwark',
#  'dowhatfeelsgood',
#  'toddweaver',
#  'supremacistrapist',
#  'oncewellshe',
#  'greenthumb',
#  'extravagances',
#  'convolutions',
#  'yidische',
#  'gardère',
#  'performeri',
#  'febres',
#  'swans',
#  'unreasonablebr',
#  'early60s',
#  'xaviersbr',
#  'ekman',
#  'politicalsocial',
#  'reagher',
#  'coulthard',
#  'smorsgabord',
#  'ashoks',
#  'colorwhich',
#  'joannons',
#  'flightbr',
#  'agebut',
#  'miroku',
#  'buchholz',
#  'giubba',
#  'townspeoplebr',
#  'addictivebr',
#  'cerabal',
#  'dbz',
#  'numerically',
#  'siteconsider',
#  'boulevardbr',
#  'hardliving',
#  'unsuspected',
#  'villers',
#  'provisions',
#  'gradeschoolers',
#  'europeshow',
#  'researchedbr',
#  'takechis',
#  '₤250000',
#  'reincarnations',
#  'ingasp',
#  'emperorloyal',
#  'lookwhatwecanalsodomum',
#  'wordly',
#  'penzance',
#  'flm',
#  'drawerbr',
#  'almostdead',
#  'inish',
#  'mazzellos',
#  'manofwar',
#  'exhuman',
#  'abbad',
#  'takersthe',
#  ...]

# %%
print(len(noise_words))
prep_txt=filtered_prep_txt
# Out:
# 142367

# %%
words_counter = Counter(prep_txt.split())

words_df = pd.DataFrame(words_counter.items(), columns=['word', 'count'])
words_df.sort_values(by=['count'], ascending=False, inplace=True)
print(f"no of unique words={len(words_df)}\nno of words ={words_df['count'].sum()}")
# Out:
# no of unique words=17943
# no of words =5189833

# %%
r=cnt_ranges(words_df,10,'count')

# %%
pd.DataFrame(r,columns=["range",'cnt']).head(100)
# Out:
#            range   cnt
# 0       10 to 20   512
# 1       20 to 30  3929
# 2       30 to 40  2319
# 3       40 to 50  1606
# 4       50 to 60  1165
# ..           ...   ...
# 95    960 to 970    11
# 96    970 to 980     8
# 97    980 to 990     4
# 98   990 to 1000    17
# 99  1000 to 1010    11
#
# [100 rows x 2 columns]

# %%
words_df[words_df['count']<100]
# Out:
#                  word  count
# 3901         christie     99
# 10866            1945     99
# 7894           akshay     99
# 6803            bombs     99
# 5024           motive     99
# ...               ...    ...
# 14749           nasal     20
# 17479          dealbr     20
# 16001  anthropologist     20
# 13613      songwriter     20
# 16294       sullivans     20
#
# [12074 rows x 2 columns]

# %%
src.get_head_mid_tail(words_df,1000)
# Out:
#                  word  count
# 31              movie  66976
# 73               film  59411
# 62                his  45522
# 130              just  28030
# 129                if  26971
# ...               ...    ...
# 14749           nasal     20
# 17479          dealbr     20
# 16001  anthropologist     20
# 13613      songwriter     20
# 16294       sullivans     20
#
# [3000 rows x 2 columns]

# %%
raw_reviews_txt[:250]
# Out:
# 'I grew up (b. 1965) watching and loving the Thunderbirds. All my mates at school watched. We played "Thunderbirds" before school, during lunch and after school. We all wanted to be Virgil or Scott. No one wanted to be Alan. Counting down from 5 becam'

# %%
prep_txt[:250]
# Out:
# 'grew up b 1965 watching loving thunderbirds my mates school watched we played thunderbirds before school during lunch after school we wanted virgil scott no wanted alan counting down 5 became art form took my children see movie hoping would get glimp'

# %%
# save preprocessed reviews
with open(os.path.join(prep_dataset_dir, "reviews.txt"), 'w') as reviews_file:
    reviews_file.write(prep_txt)

# %%
prep_words_counter = Counter(prep_txt.split())
prep_words_df = pd.DataFrame(prep_words_counter.items(), columns=['word', 'count'])
print(f"no of unique words={len(prep_words_df)}\nno of words ={prep_words_df['count'].sum()}")
prep_words_df.sort_values(by=['count'], ascending=False, inplace=True)
# Out:
# no of unique words=17943
# no of words =5189833

# %%
prep_words_df.head(100)
# Out:
#         word  count
# 31     movie  66976
# 73      film  59411
# 62       his  45522
# 130     just  28030
# 129       if  26971
# ..       ...    ...
# 65    should   7690
# 327  through   7646
# 120    those   7593
# 251       im   7563
# 783     back   7446
#
# [100 rows x 2 columns]

# %% [markdown]
# - only `.` is removed with size `327192` , it was the second most frequent word , the std will decrease a little

# %%
prep_words_df.describe()
# Out:
#               count
# count  17943.000000
# mean     289.239982
# std     1373.175361
# min       20.000000
# 25%       31.000000
# 50%       56.000000
# 75%      143.000000
# max    66976.000000

# %%
prep_reviews_list = prep_txt.split('\n')
len(prep_reviews_list)
# Out:
# 40000

# %%
prep_words_counter['séance']
# Out:
# 0

# %% [markdown]
# # Skip-Gram Data loader
# - Dataset Loader will load the txt data
# - count the frequency for each word and total frequency which used in selecting the noise words which doesn't appear in the word context
# - save a map for word to index and index to word , change txt to int
# - iterate over the data , return each iteration the target which is the no of words around the given word with size `w` and the input will be the word repeated `w` times
#     - ex if the txt is 'They celebrated his birthday with a big party.' and we are at the word 'birthday' and the window size = 4
#         - input `[birthday,birthday,birthday,birthday]` target `[celebrated,his,with,a] `
#
# - probability distribution of selecting a word

# %%
with open(os.path.join(prep_dataset_dir, 'reviews.txt')) as prep_file:
    prep_txt = prep_file.read()
prep_reviews_list = prep_txt.split('\n')
len(prep_reviews_list)
# Out:
# 40000

# %%
rev_skip_gram_data = src.Word2VecDataset(prep_txt, window_size=5, no_noise_outputs=25, batch_size=256)

# %%
rev_skip_gram_data.save_word2int(prep_dataset_dir)

# %%
for word in prep_words_counter.keys():
  if word not in rev_skip_gram_data.word2int:
    print(word)

# %%
word2intx=src.utils.load_json(os.path.join(prep_dataset_dir,"word2int.json"))

# %%
print(f"int value for amazing {word2intx['amazing']}")
print(f"int value for good {word2intx['good']}")
# Out:
# int value for amazing 444
# int value for good 6

# %%
itrr = iter(rev_skip_gram_data)
word, target, noise = next(itrr)

# %%
print(f"words_in shape {word.shape}")
print(f"target_words shape {target.shape}")
print(f"noise_words shape {noise.shape}")
# Out:
# words_in shape torch.Size([1526])
# target_words shape torch.Size([1526])
# noise_words shape torch.Size([1526, 25])

# %%
rev_skip_gram_data.no_unique_words
# Out:
# 17944

# %%
import torch
from torch import optim
import numpy as np
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# instantiating the model
embedding_dim = 300
model = src.SkipGram(rev_skip_gram_data.no_unique_words, embedding_dim).to(device)

# %% [markdown]
# # Training

# %%
# using the loss that we defined
criterion = src.NegativeSamplingLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

epochs = 25

# %%
latest_weights_path=traintracker.latest_weights_path(weights_dir)
print(latest_weights_path)
state_dict=torch.load(latest_weights_path)
model.load_state_dict(state_dict)
# Out:
# /content/drive/MyDrive/projects/sentiment-analysis-RNN/model_weights/skipgram/12_04 17_53 Train_(3.66341) .pt
# <All keys matched successfully>

# %%
notes="add nromalization from -3 to 3"

# %%
src.skipgram_train(model=model,epochs=epochs,skip_gram_data=rev_skip_gram_data,device=device,optimizer=optimizer,criterion=criterion,train_data_dir=train_data_dir,weights_dir=weights_dir)
# Out:
#  epoch 1[..........]time remaining (m) = 9.44 Avg Train_Loss=30.11185708Epoch: 1/25
# Loss:  12.038331985473633
# film | dont, make, movie, movies, bad
# think | evil, whole, actually, back, american
# made | impressive, tell, no, well, same
# them | if, make, we, remember, really
# watch | film, even, –, see, making
# really | left, where, women, girl, only
# well | would, each, film, james, made
# better | though, side, after, films, loved
# former | underground, independent, passions, demons, seeks
# younger | flaw, carey, jacket, effort, footage
# college | somehow, fairly, spot, political, waybr
# sweet | sounds, love, characters, does, argue
# sadly | no, sculpture, statement, nearly, page
# suddenly | quite, veteran, may, during, before
# spend | best, bloody, eitherbr, minutes, dont
# casting | lesson, soundtrack, completely, let, every
# ...
#
#  epoch 1[=.........]time remaining (m) = 7.83 Avg Train_Loss=19.41773969Epoch: 1/25
# Loss:  6.70511531829834
# characters | through, always, films, god, well
# scene | successful, strictly, if, few, mission
# also | might, say, just, see, guy
# character | lopez, miss, only, being, walter
# into | know, fall, too, even, fails
# good | knew, more, just, ive, really
# best | than, ive, reason, couple, herself
# were | his, costello, much, eat, elegant
# band | risks, critics, very, unknowns, improve
# italian | butler, capshaw, sea, blow, diabolical
# hair | family, woody, adapted, darius, sleep
# former | underground, coincidences, independent, seeks, passions
# social | buddy, than, significant, off, elijah
# wrote | true, end, examination, course, dominant
# intelligent | mostly, worthwhile, under, mars, where
# audiences | roles, flaw, adventure, episodes, columbo
# ...
#
#  epoch 1[==........]time remaining (m) = 6.78 Avg Train_Loss=14.96590867Epoch: 1/25
# Loss:  5.3593430519104
# such | movie, after, seen, if, give
# me | film, movie, even, very, being
# show | been, good, just, him, pretty
# time | just, when, movie, no, film
# had | get, story, would, because, even
# where | really, most, she, will, movie
# him | than, only, more, no, been
# ever | think, back, films, much, giving
# social | than, off, teutonic, does, better
# 7 | when, less, stupid, admiral, movie
# spend | bloody, eitherbr, dont, best, advert
# compared | white, approximately, emotionally, product, massacre
# former | underground, coincidences, passions, foxx, films
# bored | do, lowbudget, buffalo, concerning, gender
# died | cheaper, unusual, anachronisms, pretty, pictured
# convincing | armageddon, reed, spectacularly, cube, dmytryk
# ...
#
#  epoch 1[===.......]time remaining (m) = 5.73 Avg Train_Loss=12.52522748Epoch: 1/25
# Loss:  4.7301130294799805
# plot | film, story, very, acting, little
# just | film, movie, which, no, time
# something | we, just, even, no, over
# well | film, would, story, very, movie
# first | movie, when, then, which, up
# never | just, seen, movie, film, while
# great | film, very, movie, were, story
# still | only, would, being, just, movie
# compared | white, approximately, emotionally, product, try
# flat | them, represented, then, novelist, immaculate
# spend | bloody, eitherbr, advert, naked, funniest
# rate | musician, idea, surprise, times, person
# died | cheaper, unusual, show, anachronisms, hanson
# cold | brandos, train, beals, hitler, romantic
# force | chains, takes, critters, smacks, total
# pointless | ruin, really, still, script, writing
# ...
#
#  epoch 1[====......]time remaining (m) = 4.73 Avg Train_Loss=10.98376413Epoch: 1/25
# Loss:  4.762303352355957
# well | film, very, story, would, which
# something | just, even, we, movie, more
# too | even, much, because, very, more
# after | when, then, she, being, had
# say | if, think, see, just, movie
# why | if, make, can, really, how
# better | more, would, even, could, much
# story | very, film, which, well, movie
# likes | romance, actually, fly, watch, never
# project | lead, screenplay, scene, take, each
# tension | performances, preach, characters, feel, sheer
# neither | thought, interesting, humorless, medicine, van
# recent | souls, failed, fit, equation, stupidbr
# bizarre | find, though, fairly, filmbr, asian
# casting | just, lesson, soundtrack, good, experience
# suddenly | back, get, when, then, quite
# ...
#
#  epoch 1[=====.....]time remaining (m) = 3.76 Avg Train_Loss=9.91904493Epoch: 1/25
# Loss:  4.564263820648193
# how | can, we, if, really, do
# movie | film, if, just, movies, even
# could | would, had, can, should, just
# get | will, can, see, how, if
# plot | story, acting, just, very, film
# being | which, also, only, when, man
# too | even, much, very, because, just
# these | were, them, two, many, other
# cold | brandos, husband, she, beals, hitler
# common | obvious, giving, racist, keep, goodies
# intelligent | mostly, worthwhile, work, direction, mars
# awesome | overall, gives, think, woodland, really
# longer | better, much, track, requests, more
# dancing | 15, later, coming, every, soundtrack
# fear | love, own, find, opened, exceptions
# convincing | though, reed, dmytryk, looks, dies
# ...
#
#  epoch 1[======....]time remaining (m) = 2.81 Avg Train_Loss=9.13886518Epoch: 1/25
# Loss:  4.52517032623291
# does | did, also, doesnt, can, here
# she | him, his, when, man, where
# really | even, just, because, movie, think
# should | would, could, had, can, will
# those | these, most, will, such, only
# we | them, how, can, people, know
# film | movie, which, films, also, very
# character | also, which, characters, his, role
# bizarre | find, though, maybe, nice, each
# tension | characters, performances, plot, no, here
# spend | bloody, watching, funniest, watch, previous
# company | deep, ie, did, lot, again
# suddenly | back, when, then, gets, she
# flat | little, ending, them, point, immaculate
# era | means, films, work, already, bipolar
# common | keep, true, obvious, giving, racist
# ...
#
#  epoch 1[=======...]time remaining (m) = 1.88 Avg Train_Loss=8.54173546Epoch: 1/25
# Loss:  4.245203018188477
# up | when, into, then, while, where
# even | just, really, because, think, still
# than | much, more, even, far, better
# such | which, film, only, most, also
# dont | do, if, didnt, can, would
# would | could, should, can, had, if
# end | where, then, when, which, way
# never | only, just, because, had, now
# successful | making, entertaining, seems, part, been
# younger | young, woman, once, because, man
# speak | problem, need, german, understand, do
# involving | story, begins, end, making, run
# century | major, guarantee, world, roger, couple
# uses | killing, drama, cast, group, john
# company | deep, release, man, had, evil
# flat | ending, enough, little, sad, simply
# ...
#
#  epoch 1[========..]time remaining (m) = 0.94 Avg Train_Loss=8.06886027Epoch: 1/25
# Loss:  4.256879806518555
# better | more, much, would, less, than
# too | pretty, much, quite, still, very
# your | my, want, if, watch, go
# than | much, more, even, better, far
# best | worst, most, great, director, ive
# make | makes, think, do, really, even
# very | quite, also, well, pretty, story
# him | she, his, man, them, then
# violent | typical, course, quite, , scenes
# band | cast, show, soundtrack, also, including
# younger | young, woman, man, sister, girlfriend
# decide | going, want, their, turns, stay
# office | called, here, thats, episode, family
# died | now, saw, came, show, loved
# mentioned | others, among, anything, seen, times
# popular | produced, being, watched, wars, also
# ...
#
#  epoch 1[=========.]time remaining (m) = 0.0 Avg Train_Loss=7.68532608Epoch: 1/25
# Loss:  4.269071578979492
# she | him, shes, girl, hes, man
# when | after, before, then, where, first
# will | can, may, would, those, want
# him | she, his, hes, them, man
# if | think, really, movie, see, because
# did | does, didnt, do, doesnt, would
# off | then, into, up, down, when
# bad | good, just, really, acting, awful
# werent | maybe, wasnt, got, fun, arent
# decide | want, going, stay, your, them
# visual | music, somewhat, simple, style, emotional
# created | such, most, however, also, truly
# pointless | just, thats, writing, boring, ending
# italian | american, most, films, being, those
# hold | take, live, kids, oh, keep
# public | live, power, unfortunately, into, still
# ...
#
#  training epoch 1 time Taken (m) = 9.33 Avg Train_Loss=7.68498283
#  epoch 1 train_loss =7.68498283  total_time= 9.33
#  epoch 2[..........]time remaining (m) = 8.73 Avg Train_Loss=4.12027881Epoch: 2/25
# Loss:  4.175135135650635
# really | just, because, actually, think, good
# them | their, people, we, him, these
# through | into, then, while, way, down
# little | much, bit, also, while, seems
# something | if, someone, anything, just, actually
# than | much, more, less, far, even
# im | am, now, thats, movie, if
# scene | scenes, where, almost, which, when
# producers | writers, because, thought, such, should
# created | most, such, also, well, often
# likes | band, forget, recommend, french, course
# list | ones, such, time, show, any
# popular | produced, american, hollywood, known, different
# entirely | completely, terrible, almost, interesting, such
# secret | under, world, evil, goes, place
# century | place, world, set, modern, roger
# ...
#
#  epoch 2[=.........]time remaining (m) = 7.51 Avg Train_Loss=4.11013294Epoch: 2/25
# Loss:  4.074899196624756
# then | back, off, when, just, after
# those | these, many, such, most, people
# story | plot, film, which, very, movie
# such | which, also, those, truly, most
# more | better, less, rather, much, than
# if | something, think, do, actually, because
# show | series, movie, shows, tv, think
# can | will, could, cant, would, must
# appreciate | enjoy, filmmakers, think, anyone, fans
# audiences | viewers, audience, certainly, today, film
# created | most, such, also, amazing, which
# former | his, son, plays, man, wife
# fantasy | horror, fans, such, drama, genre
# project | himself, least, budget, did, would
# consider | think, found, understand, serious, probably
# century | set, place, modern, world, live
# ...
#
#  epoch 2[==........]time remaining (m) = 6.58 Avg Train_Loss=4.10111567Epoch: 2/25
# Loss:  4.118417263031006
# ever | ive, worst, seen, probably, never
# had | could, would, since, should, having
# scene | scenes, sequence, where, almost, which
# watch | see, watching, enjoy, want, seeing
# his | him, himself, father, their, whose
# could | would, should, can, had, might
# something | someone, anything, nothing, if, actually
# just | really, because, actually, movie, think
# werent | arent, were, maybe, got, think
# train | while, starts, eventually, house, them
# recommended | recommend, enjoy, entertaining, watch, overall
# fear | own, those, level, pure, without
# convincing | believable, good, decent, very, effective
# violent | violence, scenes, typical, itself, being
# sees | him, woman, living, she, named
# filled | action, subtle, dialogue, most, kind
# ...
#
#  epoch 2[===.......]time remaining (m) = 5.6 Avg Train_Loss=4.09260812Epoch: 2/25
# Loss:  4.085705757141113
# people | them, things, those, how, kids
# then | when, just, back, finally, instead
# your | my, want, watch, yourself, money
# being | while, which, having, actually, because
# great | excellent, good, wonderful, also, fine
# movies | films, movie, film, seen, flick
# had | could, since, should, would, been
# while | which, although, way, also, course
# villain | played, character, plays, role, guy
# intelligent | funny, humor, very, comedy, kind
# amount | gore, violence, sex, theres, sick
# situations | characters, completely, stupid, things, scenes
# yeah | oh, thats, girl, now, right
# social | political, such, society, without, message
# office | box, large, called, whose, living
# hold | keep, take, live, get, come
# ...
#
#  epoch 2[====......]time remaining (m) = 4.65 Avg Train_Loss=4.08491034Epoch: 2/25
# Loss:  4.036843299865723
# she | shes, herself, woman, him, girl
# over | then, again, top, once, while
# made | makes, make, making, had, seen
# these | those, two, were, many, them
# no | any, only, real, theres, nothing
# also | both, which, here, although, however
# end | ending, until, beginning, final, ends
# where | when, course, which, during, scene
# mentioned | seen, already, said, here, others
# likes | heard, band, thinks, recommend, course
# company | release, local, decides, studio, sell
# fantasy | drama, fans, horror, reality, modern
# century | place, 20th, set, modern, which
# former | his, son, plays, father, wife
# state | war, world, our, where, political
# language | speak, english, violence, nudity, subtitles
# ...
#
#  epoch 2[=====.....]time remaining (m) = 3.71 Avg Train_Loss=4.07770376Epoch: 2/25
# Loss:  4.086398601531982
# two | three, four, these, couple, both
# films | movies, film, movie, cinema, hollywood
# if | think, because, just, anyone, really
# can | could, cant, will, would, must
# way | seems, just, however, course, almost
# even | actually, just, really, think, still
# into | through, then, while, off, instead
# man | woman, boy, young, girl, hes
# fear | human, own, sexual, life, sense
# likes | thinks, kind, recommend, band, french
# images | music, truly, which, scenes, often
# german | american, english, british, french, japanese
# rate | 10, rating, give, watch, 1
# secret | government, under, evil, new, kill
# speak | english, understand, language, need, words
# waiting | until, going, then, would, finally
# ...
#
#  epoch 2[======....]time remaining (m) = 2.79 Avg Train_Loss=4.07088328Epoch: 2/25
# Loss:  3.9623966217041016
# very | quite, extremely, pretty, also, particularly
# can | cant, could, will, must, would
# were | these, theyre, especially, both, actors
# them | him, people, try, their, these
# no | any, theres, real, only, nothing
# did | didnt, does, do, would, can
# two | three, four, these, 3, couple
# think | really, say, know, probably, just
# hold | keep, take, get, live, your
# amount | violence, gore, lack, theres, sex
# state | world, war, social, human, country
# consider | think, found, perhaps, certainly, viewers
# successful | entertaining, making, clearly, project, seems
# popular | hollywood, american, known, produced, famous
# office | box, called, living, large, city
# list | opinion, ones, absolute, top, 100
# ...
#
#  epoch 2[=======...]time remaining (m) = 1.86 Avg Train_Loss=4.06454692Epoch: 2/25
# Loss:  3.997939348220825
# love | loved, hate, true, however, beautiful
# could | would, should, might, can, had
# something | anything, nothing, someone, things, everything
# where | when, which, course, during, scene
# character | characters, role, actor, played, fact
# seen | ive, heard, watched, ever, worst
# than | less, more, much, better, far
# end | until, ending, beginning, final, ends
# violent | violence, typical, sexual, scenes, nature
# project | budget, obviously, director, direct, successful
# aside | mostly, simply, despite, enough, none
# secret | government, agent, under, which, mysterious
# company | studio, release, local, sell, radio
# public | audiences, audience, free, filmmakers, american
# died | dies, after, father, dying, before
# fantasy | traditional, horror, drama, story, reality
# ...
#
#  epoch 2[========..]time remaining (m) = 0.93 Avg Train_Loss=4.05872759Epoch: 2/25
# Loss:  4.026251316070557
# best | worst, greatest, most, favorite, great
# first | last, second, after, when, during
# * | alexs, dw, location, medal, backdrop
# man | woman, guy, boy, girl, hes
# should | would, could, might, must, had
# how | why, really, we, people, fact
# still | now, however, while, quite, although
# him | them, his, himself, she, hes
# filled | full, plenty, action, such, lots
# hair | wearing, looks, eyes, face, red
# biggest | worst, major, only, big, greatest
# neither | nor, enough, kind, particularly, anything
# train | car, wreck, ship, while, city
# flat | just, simply, dialogue, annoying, uninteresting
# fantasy | romance, reality, traditional, horror, drama
# era | hollywood, films, 70s, early, late
# ...
#
#  epoch 2[=========.]time remaining (m) = 0.0 Avg Train_Loss=4.05320466Epoch: 2/25
# Loss:  4.032414436340332
# two | three, four, couple, both, several
# im | am, youre, myself, wasnt, now
# off | then, into, head, away, down
# really | actually, because, just, either, think
# characters | character, actors, situations, them, stories
# any | no, anything, either, even, real
# been | had, gotten, worked, thought, already
# very | quite, extremely, pretty, particularly, fairly
# younger | older, young, sister, brother, mother
# awesome | great, amazing, cool, liked, excellent
# uses | use, using, used, style, appears
# suddenly | when, then, finally, eventually, soon
# era | early, hollywood, late, 70s, silent
# entirely | completely, totally, seems, somewhat, utterly
# moves | starts, moving, slow, pace, move
# list | top, among, opinion, 100, absolute
# ...
#
#  training epoch 2 time Taken (m) = 9.29 Avg Train_Loss=4.05319312
#  epoch 2 train_loss =4.05319312  total_time= 9.29
# new minimum train loss 4.05319312  achieved, model weights saved
#  epoch 3[..........]time remaining (m) = 8.99 Avg Train_Loss=3.92432333Epoch: 3/25
# Loss:  3.910280466079712
# me | viewer, actually, just, us, my
# when | where, before, then, finally, after
# better | more, worse, less, expected, rather
# good | great, excellent, bad, decent, nice
# also | which, although, both, however, particularly
# over | then, again, top, once, after
# how | why, really, we, fact, people
# does | doesnt, did, didnt, do, may
# 7 | 10, 3, 8, 4, 6
# biggest | major, worst, big, only, greatest
# werent | were, arent, wasnt, maybe, wouldnt
# company | studio, release, sell, business, local
# band | rock, songs, soundtrack, singer, music
# villain | character, evil, plays, hero, role
# entirely | completely, totally, somewhat, seems, almost
# created | create, creating, made, such, world
# ...
#
#  epoch 3[=.........]time remaining (m) = 7.63 Avg Train_Loss=3.92688901Epoch: 3/25
# Loss:  3.942338466644287
# made | makes, making, make, seen, produced
# do | did, dont, didnt, doing, does
# me | us, actually, viewer, really, just
# even | actually, any, really, certainly, enough
# plot | storyline, story, script, dialogue, dialog
# films | movies, film, flicks, movie, cinema
# ever | worst, ive, probably, seen, funniest
# character | characters, role, actor, played, plays
# trouble | while, getting, problems, back, then
# mad | scientist, dr, house, monster, evil
# scott | mr, plays, john, played, thomas
# popular | famous, american, hollywood, british, current
# likes | recommend, thinks, wants, fans, id
# rate | rating, give, 10, grade, gave
# consider | think, recommend, recommended, experience, probably
# waiting | until, going, wait, then, next
# ...
#
#  epoch 3[==........]time remaining (m) = 6.66 Avg Train_Loss=3.92909307Epoch: 3/25
# Loss:  3.936760902404785
# acting | writing, direction, performances, script, dialogue
# think | know, say, probably, maybe, if
# movie | film, moviebr, movies, filmbr, really
# scene | scenes, sequence, moment, sequences, shot
# first | second, last, when, only, during
# go | get, went, goes, want, buy
# plot | story, storyline, script, dialogue, dialog
# only | least, whole, actually, because, however
# likes | thinks, wants, whos, loves, recommend
# ultimately | toward, however, seems, result, somewhat
# scott | mr, john, thomas, plays, played
# consider | think, recommend, experience, recommended, thought
# audiences | viewers, audience, us, viewer, filmmakers
# language | speak, english, subtitles, content, violence
# science | fiction, scifi, mystery, 3000, history
# disney | cartoon, animated, animation, cartoons, movies
# ...
#
#  epoch 3[===.......]time remaining (m) = 5.68 Avg Train_Loss=3.93102602Epoch: 3/25
# Loss:  3.979987859725952
# up | together, off, back, around, across
# did | didnt, does, do, dont, would
# love | loved, hate, romantic, beautiful, romance
# great | wonderful, excellent, good, fantastic, fine
# she | shes, herself, woman, girl, him
# better | more, worse, less, than, funnier
# im | am, youre, wasnt, ok, myself
# well | nicely, also, poorly, very, good
# entirely | completely, totally, seems, utterly, almost
# singing | dancing, songs, song, dance, musical
# aside | none, despite, mostly, which, quite
# basic | itself, plot, premise, good, simple
# credit | director, praise, kudos, deserves, effort
# cold | dark, walk, winter, feeling, alone
# era | early, hollywood, late, 70s, period
# sick | stupid, now, crazy, sorry, twisted
# ...
#
#  epoch 3[====......]time remaining (m) = 4.72 Avg Train_Loss=3.93212741Epoch: 3/25
# Loss:  3.9350876808166504
# me | us, viewer, myself, my, just
# really | just, because, actually, overall, quite
# them | him, themselves, people, their, these
# first | second, last, third, when, during
# been | gotten, had, done, worked, taken
# well | also, poorly, nicely, good, very
# time | timebr, money, when, hour, week
# over | again, then, top, once, later
# former | named, plays, his, whose, played
# sweet | charming, cute, romantic, romance, little
# fear | feeling, ultimate, sense, feelings, desire
# bizarre | strange, weird, which, odd, surreal
# era | early, hollywood, 70s, late, period
# hold | keep, come, get, stand, pick
# project | budget, successful, obviously, director, effort
# language | speak, english, content, subtitles, violence
# ...
#
#  epoch 3[=====.....]time remaining (m) = 3.77 Avg Train_Loss=3.93307722Epoch: 3/25
# Loss:  3.91093373298645
# never | before, once, since, already, ever
# end | ending, beginning, ends, ended, until
# off | then, down, onto, back, up
# bad | awful, terrible, good, horrible, stupid
# even | actually, just, certainly, any, really
# best | worst, greatest, favorite, funniest, finest
# little | bit, much, more, however, lot
# love | hate, tells, romantic, romance, loved
# intelligent | entertaining, smart, witty, highly, funny
# era | early, hollywood, 70s, period, silent
# band | rock, bands, singer, soundtrack, group
# recent | films, earlier, previous, movies, since
# likes | thinks, recommend, wants, loves, looking
# state | government, states, country, germany, world
# images | imagery, shots, scenes, visual, which
# credit | director, praise, kudos, deserves, effort
# ...
#
#  epoch 3[======....]time remaining (m) = 2.84 Avg Train_Loss=3.93360561Epoch: 3/25
# Loss:  3.9182095527648926
# why | how, because, think, whether, exactly
# im | am, youre, now, wasnt, myself
# see | watch, rent, know, say, buy
# how | why, really, too, believe, we
# well | nicely, poorly, beautifully, very, good
# because | really, just, why, think, maybe
# something | anything, nothing, everything, someone, just
# movies | films, movie, flicks, film, comedies
# company | studio, sell, business, local, companies
# intelligent | entertaining, witty, smart, funny, interesting
# sweet | cute, charming, romance, little, romantic
# yeah | oh, yes, thats, now, ok
# suddenly | when, soon, then, eventually, finally
# likes | thinks, wants, loves, recommend, knows
# century | 20th, 19th, england, early, worlds
# aside | just, despite, simply, none, mostly
# ...
#
#  epoch 3[=======...]time remaining (m) = 1.89 Avg Train_Loss=3.93415106Epoch: 3/25
# Loss:  3.8941330909729004
# could | would, can, should, might, had
# even | actually, certainly, really, any, just
# life | lives, lifebr, family, world, living
# bad | awful, good, terrible, horrible, poor
# great | excellent, wonderful, good, fantastic, terrific
# if | unless, whether, wouldnt, think, really
# my | your, me, watched, saw, mine
# show | shows, series, television, episode, episodes
# singing | dancing, song, songs, dance, musical
# credit | director, kudos, deserves, effort, deserved
# store | local, shop, bin, video, home
# produced | directed, made, filmed, written, production
# yeah | oh, yes, thats, says, now
# fear | ultimate, feeling, desire, tragedy, sense
# decides | wants, finds, him, plans, needs
# amount | plenty, considerable, lots, gore, violence
# ...
#
#  epoch 3[========..]time remaining (m) = 0.94 Avg Train_Loss=3.93444445Epoch: 3/25
# Loss:  3.998159170150757
# she | shes, herself, woman, him, actress
# which | also, however, film, although, sort
# did | didnt, does, do, would, dont
# something | anything, nothing, everything, someone, things
# two | three, four, couple, these, several
# very | extremely, quite, pretty, particularly, somewhat
# great | excellent, wonderful, fantastic, terrific, good
# more | less, better, rather, than, worse
# spend | spent, waste, spending, spends, money
# hold | keep, held, come, holds, stand
# company | studio, business, sell, companies, local
# producers | writers, makers, filmmakers, director, directors
# sees | finds, meets, named, tells, wants
# language | speak, english, subtitles, content, extreme
# list | bottom, imdb, top, 100, opinion
# popular | famous, successful, 50s, american, 1970s
# ...
#
#  epoch 3[=========.]time remaining (m) = 0.0 Avg Train_Loss=3.93467847Epoch: 3/25
# Loss:  3.891964912414551
# if | unless, whether, think, though, might
# these | those, them, were, two, themselves
# good | bad, decent, great, nice, excellent
# best | worst, greatest, funniest, finest, favorite
# great | wonderful, excellent, terrific, fine, good
# also | which, both, although, great, course
# bad | good, awful, terrible, horrible, poor
# better | more, worse, less, betterbr, think
# situations | characters, jokes, situation, moments, sometimes
# filled | full, featuring, lots, plenty, such
# suddenly | quickly, eventually, when, soon, then
# fantasy | romance, reality, tale, fiction, horror
# appreciate | enjoy, understand, relate, think, see
# visual | style, cinematography, lighting, use, sound
# images | visually, shots, imagery, music, truly
# flat | dull, uninteresting, boring, trite, unfunny
# ...
#
#  training epoch 3 time Taken (m) = 9.4 Avg Train_Loss=3.93468202
#  epoch 3 train_loss =3.93468202  total_time= 9.4
# new minimum train loss 3.93468202  achieved, model weights saved
#  epoch 4[..........]time remaining (m) = 9.1 Avg Train_Loss=3.86469571Epoch: 4/25
# Loss:  3.9175641536712646
# two | three, four, couple, 2, 3
# other | others, these, various, previous, those
# seen | ive, heard, watched, ever, worst
# then | when, once, soon, now, back
# just | really, simply, because, either, anyway
# than | more, less, much, better, far
# show | shows, series, television, episode, episodes
# we | our, need, know, us, learn
# convincing | believable, realistic, effective, impressive, compelling
# bizarre | strange, surreal, weird, odd, insane
# secret | government, agent, identity, mysterious, fbi
# italian | french, german, british, japanese, american
# moves | move, pace, moving, starts, goes
# entirely | completely, totally, almost, largely, utterly
# died | dying, dies, death, killed, knew
# yeah | oh, yes, thats, now, ok
# ...
#
#  epoch 4[=.........]time remaining (m) = 7.89 Avg Train_Loss=3.8704732Epoch: 4/25
# Loss:  3.873178005218506
# does | doesnt, did, do, manages, wants
# such | truly, usually, those, also, simply
# will | youll, wont, can, may, ill
# man | woman, mans, boy, guy, son
# watch | watching, rent, see, watched, enjoy
# any | anything, no, even, either, certainly
# made | makes, making, make, produced, filmed
# how | why, really, fact, too, things
# pointless | boring, stupid, ridiculous, unnecessary, endless
# 12 | 10, 8, 5, 3, 4
# mad | scientist, dr, evil, killed, crazy
# waiting | wait, hoping, looking, going, until
# involving | featuring, theres, particular, involves, particularly
# band | bands, rock, group, songs, soundtrack
# yeah | oh, yes, now, thats, ok
# hair | wearing, looks, facial, eyes, face
# ...
#
#  epoch 4[==........]time remaining (m) = 6.78 Avg Train_Loss=3.87464317Epoch: 4/25
# Loss:  3.956906318664551
# after | before, last, later, when, soon
# know | understand, think, knew, mean, need
# his | him, whose, himself, their, hes
# him | them, his, himself, she, decides
# never | once, before, ever, then, already
# here | although, also, except, however, theres
# these | those, them, two, other, many
# much | lot, far, little, anything, than
# werent | were, arent, wasnt, theyre, least
# alive | dead, body, killed, hurt, trying
# decides | wants, plans, him, finds, tries
# flat | dull, boring, uninteresting, unfunny, trite
# convincing | believable, realistic, effective, performance, impressive
# dancing | dance, singing, dancers, astaire, musical
# intelligent | witty, smart, entertaining, engaging, humorous
# hold | keep, held, holds, stand, attention
# ...
#
#  epoch 4[===.......]time remaining (m) = 5.76 Avg Train_Loss=3.87784572Epoch: 4/25
# Loss:  3.840642213821411
# here | although, except, theres, thats, also
# way | kind, ways, waybr, thing, how
# bad | good, awful, terrible, horrible, poor
# we | our, need, know, us, understand
# really | just, because, actually, itbr, movie
# time | timebr, money, moment, week, since
# something | anything, nothing, someone, everything, things
# them | him, people, their, these, themselves
# band | bands, rock, singer, group, gang
# company | business, studio, companies, sell, money
# spend | spent, waste, spends, spending, wasting
# recommended | recommend, highly, entertaining, suggest, fans
# neither | nor, enough, none, however, particularly
# singing | dancing, song, songs, dance, sing
# century | 20th, 19th, england, japan, 18th
# store | local, shop, bin, rental, video
# ...
#
#  epoch 4[====......]time remaining (m) = 4.78 Avg Train_Loss=3.8810121Epoch: 4/25
# Loss:  3.8983356952667236
# into | through, back, onto, away, around
# character | characters, role, protagonist, personality, actor
# little | bit, much, sweet, lot, cute
# she | shes, herself, woman, girl, actress
# through | along, around, into, throughout, thru
# then | when, once, suddenly, back, just
# end | ending, beginning, ended, final, endbr
# acting | performances, writing, direction, script, directing
# hold | keep, holds, held, stand, get
# ultimately | result, however, attempt, unfortunately, effort
# century | 20th, 19th, 18th, 21st, england
# science | fiction, 3000, scifi, mystery, history
# casting | acting, script, directing, editing, actors
# concept | premise, idea, plot, original, thing
# trouble | problems, drugs, started, into, further
# force | officer, terrorist, forces, air, government
# ...
#
#  epoch 4[=====.....]time remaining (m) = 3.83 Avg Train_Loss=3.88356085Epoch: 4/25
# Loss:  3.9210965633392334
# better | worse, more, funnier, less, betterbr
# off | onto, then, offbr, down, up
# even | actually, certainly, really, just, still
# life | lifebr, lives, world, living, family
# had | hadnt, could, having, got, knew
# were | werent, arent, theyre, these, had
# than | more, less, much, better, slightly
# him | them, his, himself, she, decides
# intelligent | witty, smart, entertaining, clever, engaging
# social | political, issues, cultural, satire, society
# value | entertainment, quality, factor, pure, sheer
# fit | fits, put, exist, explain, seem
# spend | spent, waste, spends, wasting, spending
# producers | writers, filmmakers, directors, makers, director
# former | plays, named, his, meets, sent
# aside | despite, simply, also, besides, mostly
# ...
#
#  epoch 4[======....]time remaining (m) = 2.87 Avg Train_Loss=3.88580548Epoch: 4/25
# Loss:  3.944918394088745
# into | through, then, away, back, around
# had | hadnt, could, would, having, were
# his | whose, him, their, himself, mans
# been | gotten, had, done, already, worked
# story | plot, storyline, tale, stories, narrative
# most | worst, best, many, more, funniest
# way | kind, manner, ways, simply, waybr
# those | these, many, them, people, ones
# list | bottom, top, imdb, 100, favorites
# value | entertainment, quality, factor, sheer, qualities
# spend | spent, waste, spends, wasting, spending
# sadly | unfortunately, short, either, although, had
# era | period, early, 70s, 1970s, hollywood
# language | speak, english, subtitles, word, speaking
# likes | loves, thinks, wants, interested, fan
# 7 | 8, 10, 4, 6, 3
# ...
#
#  epoch 4[=======...]time remaining (m) = 1.91 Avg Train_Loss=3.88784659Epoch: 4/25
# Loss:  3.881131410598755
# end | ending, beginning, ended, until, endbr
# ever | worst, ive, seen, funniest, never
# even | actually, really, just, certainly, any
# best | worst, finest, funniest, greatest, most
# scene | sequence, scenes, moment, sequences, moments
# your | my, yourself, rent, want, youll
# when | then, where, finally, until, before
# after | before, later, when, while, during
# recent | previous, later, films, earlier, past
# longer | more, less, better, long, worse
# mad | scientist, max, insane, dr, crazy
# store | local, shop, bin, rental, video
# suddenly | then, when, quickly, eventually, soon
# tension | suspense, atmosphere, excitement, builds, scares
# dancing | dance, singing, songs, musical, dancers
# mentioned | said, noted, commented, stated, agree
# ...
#
#  epoch 4[========..]time remaining (m) = 0.96 Avg Train_Loss=3.88947821Epoch: 4/25
# Loss:  3.8699166774749756
# ever | worst, seen, ive, funniest, never
# man | woman, mans, guy, men, boy
# seen | ive, heard, watched, ever, saw
# really | just, because, actually, truly, itbr
# much | lot, far, than, little, anything
# because | really, just, why, reason, either
# off | onto, offbr, then, across, away
# into | through, onto, away, around, then
# filled | full, lots, plenty, such, featuring
# trouble | problems, problem, drugs, into, deeper
# longer | more, better, less, minute, long
# popular | famous, successful, known, 1970s, produced
# yeah | oh, yes, now, thats, says
# force | forces, air, officer, terrorist, army
# van | damme, claude, jean, ford, sant
# recommended | recommend, highly, enjoyed, enjoy, suggest
# ...
#
#  epoch 4[=========.]time remaining (m) = 0.0 Avg Train_Loss=3.89093684Epoch: 4/25
# Loss:  3.9411065578460693
# time | timebr, money, when, day, while
# we | learn, ourselves, our, see, know
# because | really, just, maybe, anyway, why
# can | cant, could, cannot, will, able
# end | ending, beginning, endbr, final, ended
# them | him, themselves, people, their, these
# seen | ive, heard, watched, ever, worst
# why | how, because, whether, reason, think
# mentioned | said, commented, noted, agree, already
# public | media, audiences, audience, system, government
# choice | casting, choose, doubt, decision, idea
# social | political, satire, cultural, society, subtle
# value | entertainment, quality, factor, sheer, values
# situations | characters, situation, jokes, moments, often
# longer | more, better, less, long, minute
# 7 | 10, 8, 6, 4, 3
# ...
#
#  training epoch 4 time Taken (m) = 9.53 Avg Train_Loss=3.89094122
#  epoch 4 train_loss =3.89094122  total_time= 9.53
# new minimum train loss 3.89094122  achieved, model weights saved
#  epoch 5[..........]time remaining (m) = 9.44 Avg Train_Loss=3.83598548Epoch: 5/25
# Loss:  3.85564923286438
# film | movie, films, filmbr, moviebr, flick
# up | upbr, off, then, getting, onto
# even | actually, just, really, any, certainly
# make | makes, making, made, create, give
# still | now, today, however, remains, sure
# scene | scenes, sequence, moment, sequences, moments
# * | aplomb, dw, location, aamir, archetypal
# over | top, again, then, past, head
# force | forces, officer, air, weapons, delta
# train | wreck, car, trains, plane, station
# secret | government, agent, mysterious, identity, secrets
# language | subtitles, speak, english, content, extreme
# fit | fits, perfectly, put, exist, seem
# van | damme, helsing, sant, claude, jean
# waiting | wait, hoping, sitting, going, looking
# public | media, audiences, audience, government, viewers
# ...
#
#  epoch 5[=.........]time remaining (m) = 7.96 Avg Train_Loss=3.8422623Epoch: 5/25
# Loss:  3.802945852279663
# were | werent, arent, theyre, had, these
# me | mebr, my, us, myself, viewer
# bad | awful, good, horrible, terrible, stupid
# scene | scenes, sequence, moment, sequences, shot
# my | your, me, watched, saw, movie
# much | lot, far, little, than, anything
# very | extremely, quite, pretty, fairly, somewhat
# * | aplomb, dw, aamir, whore, archetypal
# train | wreck, car, plane, trains, station
# secret | government, agent, secrets, service, fbi
# recommended | recommend, highly, enjoyable, entertaining, watch
# mad | scientist, max, crazy, creation, run
# decides | wants, plans, finds, him, agrees
# aside | despite, apart, quite, among, besides
# value | entertainment, factor, quality, sheer, values
# created | create, creating, creates, made, produced
# ...
#
#  epoch 5[==........]time remaining (m) = 6.84 Avg Train_Loss=3.84702547Epoch: 5/25
# Loss:  3.795823574066162
# those | these, many, ones, people, if
# seen | ive, heard, watched, ever, saw
# acting | performances, direction, script, directing, writing
# we | learn, ourselves, our, see, know
# say | think, said, do, really, see
# ever | ive, worst, seen, probably, funniest
# while | whilst, when, constantly, still, after
# most | best, worst, funniest, particularly, more
# producers | writers, filmmakers, makers, producer, directors
# suddenly | then, eventually, finally, quickly, soon
# waiting | wait, hoping, going, sitting, looking
# aside | despite, however, apart, together, quite
# italian | french, american, german, mexican, japanese
# sees | finds, meets, enters, wants, discovers
# choice | casting, choose, perfect, opinion, decision
# disney | animated, cartoons, cartoon, animation, studios
# ...
#
#  epoch 5[===.......]time remaining (m) = 5.85 Avg Train_Loss=3.85102313Epoch: 5/25
# Loss:  3.843078851699829
# movie | film, moviebr, movies, flick, filmbr
# their | themselves, our, them, his, peoples
# off | offbr, onto, across, up, into
# best | worst, greatest, finest, funniest, favorite
# them | him, themselves, their, these, others
# because | really, just, why, anyway, if
# those | these, many, people, ones, such
# little | bit, much, also, lot, tiny
# sees | finds, meets, enters, returns, discovers
# pointless | boring, unnecessary, stupid, dull, awful
# alive | dead, hurt, killed, still, eaten
# public | audiences, media, viewers, audience, system
# situations | characters, situation, incidents, jokes, moments
# 12 | 10, 5, 3, 8, 7
# uses | used, using, use, tries, opens
# bizarre | strange, weird, surreal, disturbing, absurd
# ...
#
#  epoch 5[====......]time remaining (m) = 4.85 Avg Train_Loss=3.85461809Epoch: 5/25
# Loss:  3.8999228477478027
# best | worst, greatest, funniest, finest, favorite
# will | youll, wont, can, theyll, would
# film | movie, films, filmbr, flick, moviebr
# she | shes, herself, woman, actress, girl
# first | second, last, saw, final, third
# seen | ive, heard, watched, ever, saw
# never | ever, once, always, before, hadnt
# how | why, really, whether, things, we
# werent | arent, were, wasnt, wouldnt, isnt
# sees | finds, meets, wants, enters, comes
# yeah | oh, yes, now, okay, thats
# appreciate | enjoy, understand, see, enjoyed, recommend
# concept | premise, idea, plot, storyline, overall
# entirely | completely, totally, almost, utterly, largely
# ultimately | conclusion, unfortunately, result, humanity, flawed
# situations | situation, characters, jokes, incidents, moments
# ...
#
#  epoch 5[=====.....]time remaining (m) = 3.89 Avg Train_Loss=3.85787282Epoch: 5/25
# Loss:  3.9513649940490723
# show | shows, series, episode, television, tv
# your | my, yourself, want, youre, waste
# time | timebr, money, spent, waste, hour
# how | why, really, whether, people, believe
# were | werent, arent, theyre, these, wasnt
# most | best, worst, greatest, many, funniest
# life | lifebr, lives, world, memories, living
# where | when, outside, which, during, we
# college | school, students, student, class, teenage
# bored | annoyed, boring, confused, dull, scared
# train | wreck, car, plane, trains, station
# science | fiction, scifi, 3000, mystery, history
# mad | scientist, max, frankenstein, dr, creation
# bizarre | strange, surreal, weird, twisted, odd
# involving | involves, featuring, particular, turns, which
# hold | held, keep, holds, holding, come
# ...
#
#  epoch 5[======....]time remaining (m) = 2.91 Avg Train_Loss=3.86049Epoch: 5/25
# Loss:  3.9506771564483643
# love | hate, romantic, loved, romance, lovers
# end | ending, endbr, beginning, ends, ended
# should | would, could, shouldnt, must, might
# great | excellent, wonderful, good, fantastic, fine
# after | before, when, while, later, during
# even | actually, any, just, really, still
# up | upbr, off, onto, then, together
# many | several, few, numerous, lot, various
# value | entertainment, sheer, factor, quality, values
# secret | government, agent, fbi, mysterious, secrets
# bored | annoyed, boring, confused, tired, dull
# waiting | wait, sitting, hoping, going, looking
# follows | begins, follow, involves, goes, focuses
# project | blair, research, budget, obviously, effort
# successful | famous, popular, success, producer, talented
# college | school, students, student, class, friends
# ...
#
#  epoch 5[=======...]time remaining (m) = 1.94 Avg Train_Loss=3.86284836Epoch: 5/25
# Loss:  3.915137767791748
# where | when, outside, which, beginning, scene
# love | hate, loved, loves, beautiful, romantic
# way | ways, kind, manner, waybr, simply
# many | several, few, numerous, lot, those
# does | doesnt, did, do, manages, didnt
# time | timebr, money, minutes, 30, hour
# best | worst, greatest, funniest, finest, favorite
# scenes | sequences, scene, moments, shots, scenesbr
# intelligent | witty, clever, smart, powerful, entertaining
# portrayal | performance, portrays, role, plays, performances
# van | damme, sant, helsing, gus, dammes
# decide | decides, try, want, wants, go
# 7 | 8, 10, 6, 3, 5
# scott | c, george, mr, thomas, randolph
# successful | popular, famous, success, producer, ambitious
# audiences | audience, viewers, viewer, public, fans
# ...
#
#  epoch 5[========..]time remaining (m) = 0.98 Avg Train_Loss=3.86512069Epoch: 5/25
# Loss:  3.9167723655700684
# really | just, truly, because, actually, mean
# something | anything, nothing, someone, everything, things
# go | went, goes, get, going, want
# bad | good, awful, terrible, stupid, horrible
# would | could, wouldnt, id, might, should
# even | actually, really, just, although, certainly
# get | getting, got, gets, go, find
# than | more, less, much, even, better
# trouble | problems, getting, problem, into, danger
# younger | older, sister, young, parents, brother
# uses | using, use, used, tries, takes
# consider | considered, think, please, avoid, recommend
# century | 20th, 19th, 21st, 18th, england
# spend | spent, spending, waste, spends, wasting
# neither | nor, enough, none, isnt, although
# moves | moving, move, pace, slowly, scenes
# ...
#
#  epoch 5[=========.]time remaining (m) = 0.0 Avg Train_Loss=3.86714587Epoch: 5/25
# Loss:  3.860790491104126
# know | understand, think, knew, mean, see
# such | truly, hollywood, which, kind, simply
# love | hate, loved, lovers, friendship, loves
# how | why, really, whether, we, fact
# well | nicely, beautifully, perfectly, poorly, brilliantly
# man | woman, mans, guy, boy, son
# off | then, onto, offbr, away, across
# go | went, goes, get, take, going
# decide | try, decides, want, wants, find
# public | media, audiences, government, audience, system
# 7 | 8, 10, 4, 6, 3
# situations | situation, characters, incidents, unrealistic, jokes
# era | period, early, 70s, 1950s, 60s
# store | shop, local, bin, rental, video
# awesome | amazing, great, fantastic, cool, good
# aside | despite, apart, also, besides, except
# ...
#
#  training epoch 5 time Taken (m) = 9.72 Avg Train_Loss=3.86715181
#  epoch 5 train_loss =3.86715181  total_time= 9.72
# new minimum train loss 3.86715181  achieved, model weights saved
#  epoch 6[..........]time remaining (m) = 9.38 Avg Train_Loss=3.81831404Epoch: 6/25
# Loss:  3.8211097717285156
# how | why, really, fact, whether, things
# other | others, those, previous, these, various
# make | makes, making, made, create, give
# good | great, bad, decent, excellent, nice
# into | onto, through, away, around, off
# im | am, youre, wasnt, now, myself
# dont | didnt, do, doesnt, wouldnt, cant
# movie | film, moviebr, flick, movies, filmbr
# list | bottom, top, 100, among, alltime
# sees | finds, tells, meets, enters, asks
# ultimately | conclusion, result, boring, utterly, eventually
# mentioned | said, noted, agree, commented, pointed
# office | box, sign, hospital, boss, date
# value | entertainment, factor, quality, sheer, values
# decide | decides, try, want, wants, decided
# audiences | viewers, audience, viewer, public, appeal
# ...
#
#  epoch 6[=.........]time remaining (m) = 8.17 Avg Train_Loss=3.82464288Epoch: 6/25
# Loss:  3.853179693222046
# best | worst, greatest, finest, funniest, favorite
# people | folks, women, kids, them, everyone
# film | movie, filmbr, films, documentary, moviebr
# should | would, could, shouldnt, must, ought
# would | could, wouldnt, id, should, might
# if | unless, whether, think, do, really
# know | think, knew, understand, mean, see
# dont | didnt, do, wouldnt, cant, doesnt
# sadly | unfortunately, however, overall, lacking, although
# amount | considerable, amounts, plenty, violence, lots
# compared | compare, standards, comparison, unlike, comparing
# fantasy | romance, action, epic, adventure, reality
# ultimately | conclusion, utterly, boring, unfortunately, however
# cold | winter, mountain, depressed, dark, snow
# sees | finds, tells, wants, asks, enters
# recommended | recommend, highly, enjoyable, enjoy, mustsee
# ...
#
#  epoch 6[==........]time remaining (m) = 7.05 Avg Train_Loss=3.82993228Epoch: 6/25
# Loss:  3.8345367908477783
# no | whatsoever, any, theres, nothing, none
# than | more, less, much, better, although
# being | getting, having, becoming, fact, been
# other | others, previous, these, those, many
# too | pretty, very, overly, bit, quite
# movie | film, moviebr, flick, movies, filmbr
# my | your, me, watched, favorite, saw
# should | would, could, shouldnt, must, ought
# force | forces, air, officer, delta, base
# language | subtitles, english, speak, content, word
# sees | finds, tells, wants, meets, arrives
# waiting | sitting, hoping, wait, going, looking
# trouble | problems, getting, problem, killed, insists
# producers | writers, makers, filmmakers, directors, director
# villain | villains, character, hero, evil, played
# younger | older, sister, young, parents, brother
# ...
#
#  epoch 6[===.......]time remaining (m) = 6.03 Avg Train_Loss=3.83447522Epoch: 6/25
# Loss:  3.775954484939575
# were | werent, arent, theyre, these, had
# say | said, think, see, admit, saying
# too | pretty, very, overly, either, bit
# those | these, ones, people, many, them
# their | themselves, his, our, them, each
# here | although, herebr, film, usual, given
# very | extremely, fairly, pretty, quite, surprisingly
# into | onto, through, away, around, deeper
# basic | plot, typical, premise, basically, simple
# popular | famous, successful, 1970s, sixties, controversial
# moves | move, moving, pace, switches, paced
# value | entertainment, quality, factor, sheer, values
# science | fiction, 3000, mystery, scifi, technology
# sweet | cute, charming, lovely, warm, delightful
# audiences | viewers, audience, viewer, critics, public
# werent | were, arent, wasnt, isnt, theyre
# ...
#
#  epoch 6[====......]time remaining (m) = 5.02 Avg Train_Loss=3.83831539Epoch: 6/25
# Loss:  3.8525032997131348
# little | bit, much, lot, slightly, however
# after | before, later, when, while, last
# plot | storyline, story, script, premise, dialog
# movie | film, moviebr, movies, flick, filmbr
# love | hate, loved, lovers, romance, loves
# just | really, simply, because, stupid, thats
# dont | didnt, do, wont, doesnt, wouldnt
# other | others, those, these, various, many
# decides | wants, plans, him, finds, refuses
# sees | finds, discovers, arrives, decides, meets
# moves | move, moving, pace, moved, switches
# century | 20th, 19th, 21st, 18th, twentieth
# trouble | problems, getting, business, problem, pretending
# yeah | oh, yes, thats, now, okay
# spend | spent, spending, spends, waste, wasting
# werent | were, arent, wasnt, theyre, isnt
# ...
#
#  epoch 6[=====.....]time remaining (m) = 4.0 Avg Train_Loss=3.84159579Epoch: 6/25
# Loss:  3.785629987716675
# something | anything, nothing, someone, everything, things
# film | movie, films, filmbr, documentary, flick
# think | know, probably, say, believe, thought
# does | doesnt, did, do, manages, didnt
# over | again, top, then, after, past
# see | watch, rent, find, check, hear
# acting | performances, directing, direction, script, writing
# had | hadnt, having, could, would, were
# store | shop, local, bin, video, stores
# bored | annoyed, boring, confused, scared, entertained
# hold | held, holding, holds, keep, stand
# alive | dead, eaten, murdered, still, survive
# involving | involves, featuring, particular, including, include
# created | create, creating, creates, made, vision
# force | forces, air, officer, delta, terrorist
# era | period, 60s, 1950s, 70s, 50s
# ...
#
#  epoch 6[======....]time remaining (m) = 2.99 Avg Train_Loss=3.84453149Epoch: 6/25
# Loss:  3.7577457427978516
# characters | character, charactersbr, situations, protagonists, actors
# scene | scenes, sequence, moment, sequences, moments
# them | him, themselves, people, their, these
# into | then, through, away, onto, back
# over | top, again, then, once, now
# most | best, many, worst, funniest, more
# up | upbr, then, off, onto, getting
# those | these, many, people, few, if
# werent | were, arent, wasnt, theyre, isnt
# villain | villains, hero, character, evil, played
# common | denominator, terms, traditional, understanding, sort
# credit | kudos, praise, deserves, deserved, note
# fear | desire, fears, feelings, longing, dread
# intelligent | witty, smart, talented, thoughtful, thoughtprovoking
# ultimately | conclusion, result, moral, nature, ending
# office | box, success, boxoffice, store, sign
# ...
#
#  epoch 6[=======...]time remaining (m) = 2.0 Avg Train_Loss=3.84729392Epoch: 6/25
# Loss:  3.885080575942993
# had | hadnt, could, having, were, would
# can | cant, could, cannot, will, able
# made | make, makes, produced, making, seen
# * | aplomb, whore, breasts, graduates, aamir
# such | truly, example, filled, many, these
# any | anything, no, certainly, anyone, even
# scene | scenes, sequence, moment, sequences, scenebr
# could | would, can, couldve, had, couldnt
# dancing | dance, singing, astaire, songs, dancers
# spend | spent, spending, spends, waste, wasting
# project | blair, budget, effort, finance, obviously
# state | states, government, usa, current, affairs
# filled | full, lots, plenty, such, packed
# store | shop, bin, local, rental, stores
# singing | dancing, song, sing, songs, sings
# 12 | 10, 3, 7, 5, 8
# ...
#
#  epoch 6[========..]time remaining (m) = 1.0 Avg Train_Loss=3.84972632Epoch: 6/25
# Loss:  3.8570339679718018
# know | understand, think, knew, mean, realize
# where | when, outside, which, near, during
# * | aplomb, whore, graduates, aamir, scenarios
# seen | ive, heard, watched, ever, seenbr
# more | less, better, than, rather, worse
# do | dont, did, doing, does, know
# way | kind, waybr, manner, ways, means
# scenes | sequences, scene, shots, moments, scenesbr
# ultimately | conclusion, ending, nature, however, moral
# concept | premise, idea, story, storyline, original
# band | bands, rock, singer, concert, group
# wrote | written, write, directed, author, read
# portrayal | performance, portrays, depiction, portrait, plays
# company | studio, corporation, companies, business, bank
# sick | twisted, just, sad, scared, horrible
# van | damme, helsing, sant, dien, claude
# ...
#
#  epoch 6[=========.]time remaining (m) = 0.09 Avg Train_Loss=3.85184142

# %%
src.train(model=model,epochs=epochs,skip_gram_data=rev_skip_gram_data,device=device,optimizer=optimizer,criterion=criterion,train_data_dir=train_data_dir,weights_dir=weights_dir)
# Out:
#  epoch 1[..........]time remaining (m) = 17.9 Avg Train_Loss=3.42570415Epoch: 1/15
# Loss:  3.4633517265319824
# your | want, yourself, please, then, our
# best | worst, most, greatest, also, excellent
# people | them, women, these, those, everyone
# work | script, job, camera, works, director
# something | anything, nothing, things, someone, least
# still | made, though, years, while, also
# actors | cast, actor, actresses, performances, acting
# know | don, understand, think, do, say
# century | th, twentieth, st, period, set
# van | damme, dyke, sant, gus, helsing
# accent | accents, english, southern, speaking, acting
# tone | franchot, atmosphere, style, music, mood
# starring | directed, plays, stars, starred, played
# studio | mgm, studios, company, hollywood, disney
# animated | animation, cartoon, disney, cartoons, bakshi
# solid | excellent, fine, performances, great, supporting
# ...
#
#  epoch 1[=.........]time remaining (m) = 15.73 Avg Train_Loss=3.43731387Epoch: 1/15
# Loss:  3.4449784755706787
# made | makes, make, films, making, seen
# films | movies, flicks, made, cinema, seen
# most | ever, many, worst, best, lot
# him | them, himself, guy, father, wife
# through | into, along, around, sit, way
# does | doesn, did, do, job, didn
# bad | awful, acting, terrible, poor, worse
# while | after, though, then, him, still
# respect | proust, talent, dignity, hope, attention
# value | entertainment, values, shock, quality, shonky
# disturbing | shocking, brutal, scary, gruesome, gory
# control | power, domination, damage, freedom, conceive
# violent | violence, gory, graphic, brutal, sexual
# ghost | ghosts, haunted, house, spirit, creepy
# moves | pace, moved, move, picks, goes
# ultimately | its, becomes, end, dull, interesting
# ...
#
#  epoch 1[==........]time remaining (m) = 13.73 Avg Train_Loss=3.44803564Epoch: 1/15
# Loss:  3.5048277378082275
# better | worse, much, could, done, think
# here | also, character, do, nothing, don
# look | looks, looked, looking, seem, make
# great | excellent, wonderful, fine, also, fantastic
# should | could, been, will, must, don
# because | though, people, reason, why, maybe
# could | couldn, should, might, been, better
# know | don, do, understand, think, get
# mad | scientist, crazy, bizarre, evil, lugosi
# value | entertainment, values, shock, quality, crap
# law | jude, father, enforcement, mother, police
# super | powers, mario, superhero, our, hero
# visual | effects, style, photography, cinematography, sets
# tony | frank, scott, anselmo, boss, imperioli
# trip | road, vacation, weekend, camping, journey
# pointless | unnecessary, boring, stupid, minutes, bunch
# ...
#
#  epoch 1[===.......]time remaining (m) = 11.76 Avg Train_Loss=3.45755558Epoch: 1/15
# Loss:  3.4834847450256348
# another | every, yet, then, first, also
# work | director, job, script, camera, works
# way | along, also, much, through, though
# while | after, though, still, then, however
# say | think, tell, know, said, watch
# few | couple, many, several, two, three
# where | scene, during, then, how, place
# * | campell, adler, mintz, boner, reprised
# consider | think, am, ask, found, enjoy
# concept | idea, premise, ideas, plot, basic
# band | singer, rock, group, leader, members
# animated | animation, cartoon, disney, cartoons, bakshi
# dancing | dance, singing, dances, astaire, song
# smith | joseph, perry, scott, maggie, thomas
# died | killed, death, dying, suicide, lived
# mad | scientist, crazy, bizarre, lugosi, evil
# ...
#
#  epoch 1[====......]time remaining (m) = 9.77 Avg Train_Loss=3.46532434Epoch: 1/15
# Loss:  3.521387815475464
# ever | worst, ve, seen, never, most
# now | still, since, then, again, years
# going | do, go, doing, things, know
# say | think, said, know, tell, go
# character | characters, role, played, performance, actor
# way | along, also, through, think, much
# real | true, life, actual, never, here
# seen | ve, ever, watched, heard, worst
# bizarre | strange, surreal, mad, erotic, weird
# win | won, winning, awards, wins, award
# value | entertainment, values, quality, shock, shonky
# slasher | horror, flick, genre, slashers, gore
# spend | spent, waste, spends, spending, hours
# college | students, school, student, university, high
# band | rock, singer, group, leader, members
# u | government, n, f, military, us
# ...
#
#  epoch 1[=====.....]time remaining (m) = 7.82 Avg Train_Loss=3.47267142Epoch: 1/15
# Loss:  3.5167975425720215
# make | makes, made, making, get, do
# off | away, then, into, down, around
# also | great, especially, though, most, such
# such | other, also, many, these, most
# first | second, last, after, since, then
# find | found, get, watch, try, think
# scenes | scene, sequences, moments, shots, parts
# could | might, should, couldn, been, better
# adult | children, sexual, kids, adults, normal
# producers | writers, director, did, filmmakers, didn
# mad | scientist, crazy, lugosi, bizarre, hammerhead
# culture | society, pop, american, history, cultural
# hair | blond, wig, wearing, makeup, red
# accent | accents, english, southern, speaking, speak
# solid | excellent, fine, performances, great, supporting
# weren | wasn, aren, didn, these, been
# ...
#
#  epoch 1[======....]time remaining (m) = 5.86 Avg Train_Loss=3.47934571Epoch: 1/15
# Loss:  3.4509506225585938
# work | job, works, script, director, direction
# nothing | anything, something, else, everything, do
# films | movies, flicks, cinema, genre, horror
# character | characters, role, performance, played, actor
# because | people, though, think, why, maybe
# ever | worst, ve, seen, most, never
# doesn | does, didn, don, isn, did
# something | anything, nothing, someone, else, least
# heavy | handed, metal, water, wooden, deals
# consider | think, am, considered, ask, though
# tone | atmosphere, franchot, pace, harlow, mood
# solid | fine, excellent, performances, great, supporting
# appreciate | enjoy, understand, learn, fully, think
# exciting | interesting, enjoyable, entertaining, suspense, thrilling
# force | air, police, forces, tour, military
# adult | children, sexual, adults, kids, teenage
# ...
#
#  epoch 1[=======...]time remaining (m) = 3.91 Avg Train_Loss=3.48565974Epoch: 1/15
# Loss:  3.4739348888397217
# better | worse, much, done, could, do
# does | doesn, did, do, job, makes
# work | job, director, works, script, much
# m | am, sure, re, wasn, say
# watching | seeing, watch, watched, saw, viewing
# doesn | does, didn, don, isn, did
# many | few, several, most, those, these
# people | them, those, women, because, kids
# hair | blond, wearing, makeup, red, wig
# fit | fits, seem, put, doesn, deserve
# control | power, freedom, domination, conceive, damage
# died | death, dying, killed, father, mother
# pointless | boring, unnecessary, stupid, lame, terrible
# adult | sexual, children, adults, kids, parent
# failed | miserably, fails, attempt, tried, succeeds
# impossible | hard, difficult, cant, almost, couldn
# ...
#
#  epoch 1[========..]time remaining (m) = 1.96 Avg Train_Loss=3.49149469Epoch: 1/15
# Loss:  3.589143753051758
# most | many, ever, worst, best, also
# here | also, however, say, though, pretty
# make | made, makes, get, making, do
# bad | awful, terrible, horrible, acting, poor
# think | say, know, probably, don, watch
# could | couldn, might, should, been, did
# little | bit, much, also, too, nice
# though | although, also, however, while, still
# pointless | unnecessary, boring, stupid, lame, terrible
# project | witch, computer, budget, obviously, blair
# dad | mom, father, son, mother, parents
# culture | society, pop, history, american, cultural
# appreciate | enjoy, think, understand, liked, enjoyed
# producers | writers, director, directors, filmmakers, producer
# choice | casting, choices, ideal, choose, could
# trash | garbage, crap, piece, exploitation, movies
# ...
#
#  epoch 1[=========.]time remaining (m) = 0.01 Avg Train_Loss=3.49694692Epoch: 1/15
# Loss:  3.5554728507995605
# other | each, these, them, those, two
# old | year, young, older, boy, later
# director | writer, directed, directors, producer, screenplay
# because | reason, why, though, although, know
# best | worst, greatest, favorite, great, most
# show | shows, series, episode, television, season
# another | yet, first, every, also, called
# being | fact, been, getting, having, re
# moves | pace, move, moved, goes, fast
# steve | carell, mcqueen, buscemi, martin, biko
# sick | disgusting, twisted, kinda, crap, kisses
# appreciate | enjoy, understand, liked, enjoyed, think
# smith | joseph, perry, maggie, scott, thomas
# company | studio, corporation, companies, factory, funds
# bored | boring, dull, disappointed, scared, sat
# amusing | funny, hilarious, entertaining, enjoyable, comedy
# ...
#
#  training epoch 1 time Taken (m) = 19.51 Avg Train_Loss=3.49695789
#  epoch 1 train_loss =3.49695789  total_time= 19.51
#  epoch 2[..........]time remaining (m) = 18.09 Avg Train_Loss=3.40977879Epoch: 2/15
# Loss:  3.452653408050537
# through | around, down, way, along, into
# same | similar, different, year, both, another
# before | after, never, since, having, then
# plot | script, storyline, dialogue, characters, acting
# nothing | anything, something, else, everything, thing
# its | own, itself, still, overall, however
# while | after, still, though, however, around
# didn | did, doesn, don, wasn, could
# speak | language, accent, english, understand, explain
# credit | writers, give, deserves, writer, thank
# ghost | ghosts, haunted, old, supernatural, spirit
# successful | career, movies, role, married, talented
# biggest | major, big, greatest, slovik, worst
# kills | kill, killing, killed, shoots, accidentally
# mad | scientist, crazy, lugosi, evil, bizarre
# jim | carrey, john, belushi, muriel, gentleman
# ...
#
#  epoch 2[=.........]time remaining (m) = 15.8 Avg Train_Loss=3.42249284Epoch: 2/15
# Loss:  3.47951340675354
# m | am, sure, re, wasn, say
# seen | ve, ever, heard, watched, worst
# new | york, city, orleans, old, another
# director | writer, directed, directors, producer, screenplay
# thing | things, whole, actually, think, bad
# into | then, off, through, down, where
# watching | seeing, watch, watched, saw, viewing
# think | say, know, don, probably, watch
# band | rock, singer, group, leader, soundtrack
# laughing | laugh, loud, laughed, laughter, watching
# died | dying, death, father, cancer, killed
# sick | disgusting, twisted, crap, feel, kinda
# control | freedom, power, domination, self, damage
# ultimately | eventually, pretentious, its, ending, attempt
# spend | spent, spending, spends, waste, hours
# cover | box, dvd, trailer, video, misleading
# ...
#
#  epoch 2[==........]time remaining (m) = 13.77 Avg Train_Loss=3.43367751Epoch: 2/15
# Loss:  3.5119822025299072
# part | parts, role, though, roles, second
# re | m, am, aren, don, isn
# people | these, them, because, women, kids
# find | found, get, watch, finds, think
# don | do, didn, know, doesn, think
# look | looks, looking, looked, make, makes
# get | gets, getting, got, make, go
# few | couple, several, many, two, plenty
# bizarre | strange, surreal, creepy, offensive, ending
# adventure | action, adventures, fantasy, flick, western
# impressive | convincing, superb, excellent, performances, beautifully
# concept | idea, ideas, premise, plot, original
# portrayal | performance, role, played, plays, portrays
# recent | seen, films, many, produced, past
# italian | french, spanish, european, mexican, cinema
# choice | casting, choices, ideal, choose, given
# ...
#
#  epoch 2[===.......]time remaining (m) = 11.78 Avg Train_Loss=3.44297657Epoch: 2/15
# Loss:  3.442538022994995
# after | before, then, first, while, last
# here | isn, also, although, role, however
# watch | watching, watched, want, rent, go
# makes | make, made, making, does, look
# too | pretty, much, bit, quite, little
# doesn | does, didn, don, did, isn
# end | beginning, ending, final, towards, until
# another | yet, first, every, then, also
# credit | writers, deserves, writer, give, thank
# tony | scott, soprano, frank, sirico, imperioli
# failed | miserably, fails, attempt, tried, accentuates
# concept | idea, ideas, premise, plot, original
# impossible | hard, difficult, cant, couldn, don
# follows | follow, tells, runs, meets, decides
# makers | filmmakers, writers, director, directors, assumption
# force | air, tour, police, power, army
# ...
#
#  epoch 2[====......]time remaining (m) = 9.81 Avg Train_Loss=3.45153445Epoch: 2/15
# Loss:  3.514817237854004
# first | second, after, last, since, then
# find | found, get, watch, finds, yourself
# movies | films, flicks, seen, horror, genre
# something | anything, nothing, someone, least, because
# here | think, say, also, isn, do
# actors | cast, actor, performances, actresses, acting
# don | do, didn, doesn, know, please
# never | ever, before, ve, once, always
# smith | joseph, maggie, perry, pinkett, jada
# studio | studios, mgm, hollywood, production, directors
# german | french, american, english, british, russian
# singing | dancing, voice, sing, songs, sings
# band | singer, group, rock, soundtrack, music
# zombies | zombie, revolt, vampires, flesh, corpses
# bizarre | strange, surreal, creepy, dull, offensive
# awesome | cool, great, superb, excellent, incredible
# ...
#
#  epoch 2[=====.....]time remaining (m) = 7.84 Avg Train_Loss=3.45892867Epoch: 2/15
# Loss:  3.4972455501556396
# watching | seeing, watch, watched, saw, viewing
# how | why, too, people, way, know
# don | do, didn, doesn, know, want
# why | how, reason, because, did, know
# through | around, into, along, sit, way
# didn | did, doesn, don, wasn, because
# years | ago, year, later, days, months
# characters | character, actors, plot, main, dimensional
# respect | dignity, attention, proust, important, talent
# runs | run, running, goes, gets, while
# amusing | funny, entertaining, hilarious, enjoyable, quite
# spend | spent, waste, spending, hours, spends
# consider | think, considered, am, ask, myself
# effective | excellent, performances, surprisingly, impressive, clever
# makers | filmmakers, writers, director, directors, budget
# starring | stars, starred, directed, plays, played
# ...
#
#  epoch 2[======....]time remaining (m) = 5.88 Avg Train_Loss=3.46565109Epoch: 2/15
# Loss:  3.525624990463257
# don | do, didn, know, doesn, want
# re | m, am, aren, isn, know
# actors | cast, actor, performances, actresses, characters
# him | them, himself, wife, man, guy
# being | having, fact, been, getting, re
# does | doesn, did, do, job, didn
# characters | character, actors, plot, dimensional, main
# few | couple, many, several, two, those
# showed | looked, shows, shown, showing, got
# younger | older, brother, young, old, age
# effective | excellent, performances, decent, surprisingly, impressive
# smith | joseph, maggie, perry, scott, pinkett
# slasher | horror, genre, flick, slashers, gore
# impressive | excellent, convincing, amazing, great, features
# animated | animation, cartoon, disney, cartoons, batman
# german | french, english, british, american, russian
# ...
#
#  epoch 2[=======...]time remaining (m) = 3.92 Avg Train_Loss=3.47198685Epoch: 2/15
# Loss:  3.5959339141845703
# then | back, after, now, once, over
# best | worst, great, greatest, most, ever
# now | then, since, after, years, been
# same | similar, exactly, different, another, both
# those | these, many, other, people, them
# years | ago, year, days, later, months
# many | several, few, these, most, those
# doesn | does, didn, don, makes, did
# sick | disgusting, twisted, sense, crap, kinda
# super | superhero, mario, hero, ex, powers
# trouble | getting, problem, deeper, cause, himself
# heavy | handed, metal, water, style, over
# impressive | excellent, convincing, great, features, outstanding
# pointless | unnecessary, boring, stupid, terrible, lame
# exciting | enjoyable, interesting, entertaining, thrilling, suspense
# speak | language, accent, english, word, understand
# ...
#
#  epoch 2[========..]time remaining (m) = 1.97 Avg Train_Loss=3.47764253Epoch: 2/15
# Loss:  3.5571775436401367
# also | great, especially, both, though, played
# much | lot, better, too, little, far
# him | them, himself, guy, father, wife
# going | go, do, know, get, doing
# characters | character, actors, plot, main, people
# other | each, these, two, those, them
# watching | seeing, watch, watched, saw, viewing
# watch | watching, watched, enjoy, rent, seeing
# recommended | highly, recommend, cinema, fans, am
# trouble | getting, problem, himself, without, going
# focus | focuses, focused, character, main, seems
# disturbing | shocking, brutal, scary, gruesome, violence
# win | winning, won, awards, award, oscar
# weren | wasn, aren, isn, been, these
# chemistry | between, presence, relationship, charisma, performances
# bored | boring, dull, disappointed, sat, scared
# ...
#
#  epoch 2[=========.]time remaining (m) = 0.02 Avg Train_Loss=3.48300418Epoch: 2/15
# Loss:  3.494649887084961
# find | found, get, try, watch, finds
# best | worst, greatest, great, ever, most
# say | think, know, seen, said, tell
# little | bit, much, also, too, boy
# before | after, never, finally, first, since
# being | having, fact, getting, been, girl
# watching | seeing, watch, watched, saw, viewing
# much | lot, better, little, too, far
# laughing | laugh, laughed, loud, laughter, watching
# planet | earth, apes, alien, space, forbidden
# amusing | funny, entertaining, hilarious, quite, enjoyable
# bizarre | strange, surreal, creepy, erotic, ending
# exciting | interesting, enjoyable, entertaining, thrilling, suspense
# died | death, killed, dying, cancer, father
# company | corporation, studio, companies, corp, factory
# biggest | major, big, worst, greatest, slovik
# ...
#
#  training epoch 2 time Taken (m) = 19.52 Avg Train_Loss=3.48306431
#  epoch 2 train_loss =3.48306431  total_time= 19.52
# new minimum train loss 3.48306431  achieved, model weights saved
#  epoch 3[..........]time remaining (m) = 18.24 Avg Train_Loss=3.40043252Epoch: 3/15
# Loss:  3.4387407302856445
# know | don, understand, do, think, believe
# though | although, because, however, pretty, while
# does | doesn, did, do, job, didn
# after | before, first, later, while, last
# your | yourself, want, ll, our, watch
# them | him, these, themselves, people, other
# watching | seeing, watch, watched, saw, thinking
# while | after, still, though, then, him
# company | corporation, studio, companies, corp, factory
# fit | fits, put, seem, perfectly, whippet
# recommended | highly, recommend, fans, cinema, sette
# solid | excellent, fine, performances, supporting, great
# appreciate | enjoy, understand, liked, enjoyed, recommend
# adventure | action, adventures, fantasy, flick, drama
# store | shop, video, stores, local, rental
# speak | accent, language, english, word, accents
# ...
#
#  epoch 3[=.........]time remaining (m) = 15.88 Avg Train_Loss=3.41236947Epoch: 3/15
# Loss:  3.409193277359009
# will | ll, may, won, must, should
# here | however, pretty, much, though, does
# too | pretty, bit, much, because, quite
# go | get, went, goes, watch, take
# these | those, other, them, people, many
# also | both, especially, though, actually, great
# doesn | does, didn, don, isn, won
# acting | performances, directing, direction, script, performance
# speak | accent, language, english, word, accents
# singing | dancing, songs, sing, voice, sings
# italian | french, spanish, european, mexican, japanese
# books | book, novels, read, novel, reading
# ghost | haunted, ghosts, spirit, kirk, train
# former | ex, played, plays, old, named
# appreciate | enjoy, understand, enjoyed, liked, appeal
# starring | directed, plays, stars, starred, played
# ...
#
#  epoch 3[==........]time remaining (m) = 13.83 Avg Train_Loss=3.42389018Epoch: 3/15
# Loss:  3.4199602603912354
# same | similar, exactly, different, both, exact
# another | yet, every, called, also, then
# how | why, way, people, do, too
# man | woman, guy, men, him, boy
# work | director, job, works, camera, much
# while | though, after, still, around, then
# few | couple, many, several, two, these
# director | writer, directed, directors, producer, screenplay
# amount | amounts, lot, nudity, contains, gore
# effective | excellent, powerful, performances, creepy, strong
# slasher | horror, flick, genre, slashers, scream
# violent | violence, gory, sexual, disturbing, brutal
# biggest | major, big, worst, greatest, slovik
# impressive | excellent, convincing, outstanding, interesting, performances
# trip | road, vacation, journey, weekend, california
# cover | dvd, box, trailer, misleading, mass
# ...
#
#  epoch 3[===.......]time remaining (m) = 11.83 Avg Train_Loss=3.43298954Epoch: 3/15
# Loss:  3.4951276779174805
# will | ll, may, won, don, must
# these | those, them, two, other, many
# re | m, aren, am, isn, don
# funny | hilarious, comedy, laugh, amusing, jokes
# those | these, other, people, many, ones
# ever | worst, ve, seen, never, possibly
# years | ago, year, days, later, decades
# through | into, around, down, along, long
# visual | effects, style, special, lighting, cinematic
# amusing | funny, hilarious, entertaining, quite, enjoyable
# law | jude, enforcement, father, police, danny
# planet | earth, apes, space, alien, humans
# portrayal | performance, role, played, depiction, portrayed
# smith | joseph, perry, maggie, scott, pinkett
# choice | casting, choices, given, play, could
# recommended | highly, recommend, sette, fans, italian
# ...
#
#  epoch 3[====......]time remaining (m) = 9.85 Avg Train_Loss=3.44120677Epoch: 3/15
# Loss:  3.346018075942993
# going | do, will, go, know, doing
# love | loved, fall, relationship, romance, falls
# now | then, since, years, been, after
# look | looks, looked, looking, make, seem
# seen | ve, ever, watched, heard, worst
# two | three, four, these, both, couple
# through | into, around, along, down, way
# could | couldn, been, might, should, better
# planet | earth, apes, forbidden, space, alien
# heavy | handed, metal, starts, wooden, over
# runs | run, gets, running, goes, walks
# younger | older, brother, young, old, sister
# culture | pop, society, history, mythology, american
# tone | franchot, atmosphere, darker, quite, sets
# walk | walking, walked, walks, run, room
# tony | soprano, david, frank, imperioli, anselmo
# ...
#
#  epoch 3[=====.....]time remaining (m) = 7.87 Avg Train_Loss=3.44823482Epoch: 3/15
# Loss:  3.421489953994751
# films | movies, flicks, made, seen, genre
# ve | seen, ever, haven, been, since
# thing | things, whole, ever, think, bad
# great | excellent, wonderful, fine, superb, fantastic
# could | might, couldn, should, been, better
# m | am, sure, re, wasn, fan
# man | woman, guy, men, him, boy
# over | top, again, then, back, once
# mad | scientist, crazy, evil, magician, bizarre
# concept | premise, idea, ideas, basic, plot
# died | death, dying, father, killed, die
# respect | attention, dignity, proust, subject, self
# fit | fits, seem, put, diehl, neither
# adventure | action, adventures, fantasy, flick, drama
# culture | pop, society, history, american, americans
# biggest | major, big, greatest, worst, slovik
# ...
#
#  epoch 3[======....]time remaining (m) = 5.91 Avg Train_Loss=3.45486399Epoch: 3/15
# Loss:  3.5572757720947266
# know | don, do, want, think, say
# should | could, been, must, don, better
# show | shows, series, episode, tv, season
# character | characters, role, played, performance, plays
# acting | performances, directing, performance, direction, script
# ve | seen, ever, haven, since, been
# same | similar, different, both, exactly, much
# best | worst, greatest, most, excellent, great
# adventure | action, adventures, fantasy, flick, drama
# basic | instinct, premise, plot, basically, concept
# speak | accent, language, english, understand, actors
# college | school, student, students, university, professor
# walk | walking, walked, walks, run, room
# rated | rating, r, pg, rate, violence
# studio | mgm, hollywood, studios, production, disney
# starring | stars, directed, plays, starred, version
# ...
#
#  epoch 3[=======...]time remaining (m) = 3.95 Avg Train_Loss=3.46109176Epoch: 3/15
# Loss:  3.5603983402252197
# two | three, four, couple, both, few
# still | today, also, its, now, quite
# over | top, then, again, once, around
# actors | cast, actor, actresses, performances, acting
# while | after, then, though, where, also
# though | although, however, also, pretty, because
# ve | seen, ever, haven, been, worst
# few | couple, many, several, two, these
# younger | older, brother, young, old, sister
# accent | accents, english, southern, speak, speaking
# failed | miserably, fails, attempt, tried, attempted
# language | english, subtitles, profanity, nudity, foul
# zombies | zombie, revolt, people, vampires, flesh
# mad | scientist, bizarre, magician, crazy, dr
# amusing | funny, entertaining, hilarious, quite, comedy
# disturbing | shocking, brutal, scary, unsettling, gruesome
# ...
#
#  epoch 3[========..]time remaining (m) = 1.99 Avg Train_Loss=3.46673059Epoch: 3/15
# Loss:  3.5420031547546387
# love | fall, romance, falls, great, interest
# movies | films, flicks, seen, comedies, horror
# films | movies, flicks, genre, cinema, seen
# its | own, itself, however, still, also
# into | down, through, then, off, where
# been | could, ve, done, seen, should
# still | today, while, also, its, remains
# then | after, back, now, once, over
# pointless | unnecessary, boring, lame, stupid, terrible
# planet | earth, apes, forbidden, alien, space
# force | air, police, de, military, tour
# hair | makeup, blond, wig, red, wearing
# visual | lighting, effects, style, photography, cinematic
# impossible | hard, difficult, cannot, could, complicates
# win | won, awards, winning, wins, award
# dancing | dance, singing, ballroom, dances, astaire
# ...
#
#  epoch 3[=========.]time remaining (m) = 0.03 Avg Train_Loss=3.47195773Epoch: 3/15
# Loss:  3.5144011974334717
# another | every, first, yet, also, then
# other | each, these, many, those, them
# * | campell, adler, pulls, reprised, boner
# your | want, yourself, our, watch, waste
# find | found, get, finds, try, watch
# real | true, life, actual, any, great
# work | works, director, camera, job, script
# little | bit, much, nothing, boy, too
# dancing | dance, singing, dances, ballroom, astaire
# runs | run, running, gets, goes, takes
# portrayal | performance, role, portrays, plays, depiction
# failed | miserably, fails, tried, attempt, did
# focus | focuses, focused, tension, seems, character
# visual | effects, lighting, style, cinematography, art
# basic | instinct, premise, plot, basically, concept
# died | death, dying, killed, after, cancer
# ...
#
#  training epoch 3 time Taken (m) = 19.44 Avg Train_Loss=3.47203804
#  epoch 3 train_loss =3.47203804  total_time= 19.44
# new minimum train loss 3.47203804  achieved, model weights saved
#  epoch 4[..........]time remaining (m) = 14.73 Avg Train_Loss=3.38879817Epoch: 4/15
# Loss:  3.4258344173431396
# still | while, also, now, today, years
# people | them, person, because, those, don
# him | himself, them, father, guy, wife
# new | york, city, orleans, different, old
# love | romance, relationship, great, between, hate
# going | go, doing, do, will, know
# them | him, these, people, themselves, other
# think | say, know, don, guess, probably
# german | french, english, american, british, russian
# awesome | great, cool, excellent, fantastic, superb
# zombies | zombie, revolt, vampires, flesh, people
# impressive | excellent, convincing, amazing, outstanding, stunning
# law | jude, father, enforcement, brother, enforcing
# cover | dvd, box, misleading, trailer, store
# bizarre | strange, surreal, mysterious, creepy, erotic
# trip | road, vacation, visit, go, mountains
# ...
#
#  epoch 4[=.........]time remaining (m) = 12.85 Avg Train_Loss=3.4023326Epoch: 4/15
# Loss:  3.4414565563201904
# first | second, after, last, since, then
# make | makes, made, making, do, get
# didn | did, doesn, don, couldn, because
# your | want, yourself, our, watch, rent
# new | york, city, now, same, orleans
# another | every, first, him, yet, then
# too | pretty, much, bit, how, quite
# thing | things, whole, think, though, ever
# common | sense, denominator, characters, major, do
# zombies | zombie, revolt, vampires, people, flesh
# adult | sexual, children, adults, childhood, disney
# van | damme, sant, dyke, gus, helsing
# successful | popular, success, brilliant, movies, talented
# value | entertainment, quality, values, shock, artistic
# considered | consider, perhaps, possibly, certainly, since
# ultimately | pretentious, its, conclusion, ending, inevitably
# ...
#
#  epoch 4[==........]time remaining (m) = 11.18 Avg Train_Loss=3.41257165Epoch: 4/15
# Loss:  3.4623770713806152
# look | looks, looked, looking, seem, style
# over | top, again, then, back, into
# movies | films, flicks, seen, comedies, horror
# nothing | anything, something, everything, else, absolutely
# way | along, much, also, think, other
# another | every, first, then, also, yet
# best | worst, great, greatest, most, ever
# any | anything, without, much, anyone, kind
# depth | development, emotion, lacks, character, characters
# heavy | handed, metal, water, style, wooden
# studio | mgm, studios, hollywood, disney, productions
# moves | move, pace, goes, fast, camera
# laughing | laugh, loud, laughed, watching, laughter
# trash | garbage, piece, crap, movies, junk
# fit | fits, put, seem, perfectly, played
# follows | follow, goes, following, meets, revolves
# ...
#
#  epoch 4[===.......]time remaining (m) = 9.53 Avg Train_Loss=3.42175503Epoch: 4/15
# Loss:  3.3991851806640625
# does | doesn, did, do, job, didn
# first | second, last, after, then, before
# him | them, himself, father, man, guy
# here | role, think, though, say, also
# after | before, first, while, later, then
# watch | watching, watched, want, seeing, rent
# scene | scenes, sequence, where, opening, moments
# made | makes, make, making, done, seen
# moves | move, pace, goes, moved, camera
# exciting | interesting, enjoyable, entertaining, thrilling, worthwhile
# pointless | boring, unnecessary, lame, minutes, stupid
# changed | change, changes, different, forever, radically
# laughing | laugh, loud, laughed, laughter, watching
# credit | deserves, writer, writers, give, thank
# german | french, american, english, british, russian
# makers | filmmakers, director, writers, directors, budget
# ...
#
#  epoch 4[====......]time remaining (m) = 7.94 Avg Train_Loss=3.42971262Epoch: 4/15
# Loss:  3.4442968368530273
# funny | hilarious, comedy, amusing, entertaining, scary
# will | ll, may, don, won, must
# such | other, these, many, truly, most
# people | them, women, these, because, those
# acting | performances, directing, performance, actors, dialogue
# any | anything, without, kind, anyone, every
# then | back, him, into, after, once
# two | three, four, couple, between, these
# walk | walking, walked, walks, run, go
# ghost | haunted, ghosts, mysterious, spirit, supernatural
# smith | joseph, scott, maggie, perry, thomas
# steve | mcqueen, carell, martin, buscemi, biko
# zombies | zombie, revolt, vampires, people, flesh
# band | rock, singer, group, leader, song
# changed | change, changes, different, forever, radically
# disturbing | shocking, scary, brutal, gruesome, violence
# ...
#
#  epoch 4[=====.....]time remaining (m) = 6.51 Avg Train_Loss=3.43731303Epoch: 4/15
# Loss:  3.4414477348327637
# though | although, while, pretty, because, also
# films | movies, flicks, made, seen, cinema
# same | similar, both, different, old, over
# ever | worst, ve, seen, most, never
# people | them, women, men, these, because
# acting | performances, directing, performance, actors, direction
# where | scene, place, into, then, how
# will | ll, may, won, don, must
# studio | studios, mgm, hollywood, disney, production
# kills | killing, kill, killed, shoots, accidentally
# ultimately | its, sympathy, often, end, behavior
# rated | rating, r, pg, violence, rate
# store | video, shop, local, stores, grocery
# smith | joseph, perry, scott, maggie, thomas
# chemistry | between, presence, charisma, performances, actors
# younger | older, brother, young, sister, old
# ...
#
#  epoch 4[======....]time remaining (m) = 5.03 Avg Train_Loss=3.44412682Epoch: 4/15
# Loss:  3.502192258834839
# characters | character, actors, plot, people, them
# after | before, first, then, last, while
# will | ll, may, don, won, might
# * | adler, campell, reprised, boner, pulls
# any | anything, anyone, every, without, kind
# know | don, do, understand, think, want
# should | could, must, been, may, will
# character | characters, role, performance, played, plays
# former | ex, plays, later, played, old
# trip | road, vacation, visit, journey, canoe
# violent | violence, sexual, gory, brutal, graphic
# culture | pop, society, cultural, history, americans
# bizarre | strange, surreal, humorous, absurd, erotic
# dad | mom, father, parents, son, wife
# adult | children, sexual, adults, kids, teenage
# value | entertainment, values, moral, shock, quality
# ...
#
#  epoch 4[=======...]time remaining (m) = 3.44 Avg Train_Loss=3.45041484Epoch: 4/15
# Loss:  3.5090620517730713
# ever | worst, seen, ve, never, most
# character | characters, role, performance, plays, played
# few | couple, many, several, two, moments
# characters | character, actors, plot, people, main
# another | yet, every, first, then, also
# then | after, back, once, into, him
# also | great, though, especially, actually, played
# m | am, sure, re, say, wasn
# jim | carrey, gentleman, john, belushi, flynn
# situations | situation, stressful, scenes, scenarios, reactions
# steve | carell, mcqueen, martin, buscemi, biko
# impressive | excellent, great, convincing, amazing, stunning
# german | french, english, american, russian, british
# weren | wasn, aren, isn, characters, knew
# italian | french, spanish, european, mexican, cinema
# awesome | great, cool, excellent, incredible, loved
# ...
#
#  epoch 4[========..]time remaining (m) = 1.76 Avg Train_Loss=3.45628931Epoch: 4/15
# Loss:  3.5142972469329834
# years | ago, year, days, later, months
# better | worse, much, could, done, been
# because | though, people, although, why, also
# other | each, these, those, them, many
# doesn | does, didn, don, want, isn
# two | three, four, both, these, couple
# man | woman, guy, men, him, boy
# then | back, after, once, now, into
# u | f, n, american, government, k
# planet | earth, apes, alien, space, altair
# force | air, forces, tour, officer, police
# dad | mom, father, son, parents, mother
# tony | frank, plays, imperioli, soprano, sirico
# portrayal | performance, portrays, role, plays, depiction
# pointless | boring, unnecessary, stupid, lame, pretentious
# sick | disgusting, twisted, sexual, depressed, sure
# ...
#
#  epoch 4[=========.]time remaining (m) = 0.04 Avg Train_Loss=3.46145585Epoch: 4/15
# Loss:  3.4907538890838623
# most | many, ever, best, worst, such
# people | them, women, those, everyone, these
# same | similar, different, exactly, both, did
# didn | did, don, doesn, wasn, couldn
# ve | seen, ever, haven, heard, been
# new | york, city, orleans, old, another
# something | anything, nothing, someone, things, else
# where | scene, during, back, then, how
# amount | contains, lot, amounts, enough, sufficient
# animated | animation, disney, cartoon, cartoons, anime
# ultimately | attempt, rather, sometimes, its, end
# super | superhero, ex, hero, mario, robots
# trouble | getting, problem, himself, back, work
# cover | box, dvd, trailer, misleading, mass
# fit | fits, put, seem, doesn, contribute
# common | sense, denominator, major, do, helplessness
# ...
#
#  training epoch 4 time Taken (m) = 17.53 Avg Train_Loss=3.4615416
#  epoch 4 train_loss =3.4615416  total_time= 17.53
# new minimum train loss 3.4615416  achieved, model weights saved
#  epoch 5[..........]time remaining (m) = 18.34 Avg Train_Loss=3.3788849Epoch: 5/15
# Loss:  3.4750492572784424
# much | better, lot, too, little, anything
# m | am, sure, re, fan, say
# here | nothing, isn, however, also, else
# movies | films, flicks, seen, comedies, horror
# most | many, best, worst, ever, probably
# should | could, must, will, been, might
# these | those, them, two, other, many
# something | anything, nothing, someone, things, then
# died | death, dying, cancer, killed, after
# basic | instinct, premise, plot, basically, concept
# makers | filmmakers, directors, writers, director, public
# super | superhero, mario, ex, robots, powers
# ultimately | sometimes, its, end, somewhat, ending
# credit | deserves, writers, give, thank, script
# appreciate | understand, enjoy, enjoyed, learn, appeal
# failed | miserably, fails, attempt, tried, deducted
# ...
#
#  epoch 5[=.........]time remaining (m) = 16.01 Avg Train_Loss=3.39100949Epoch: 5/15
# Loss:  3.3421525955200195
# say | think, tell, m, know, said
# m | am, sure, re, fan, say
# think | probably, don, say, watch, ever
# thing | whole, things, ever, moment, actually
# do | don, did, does, make, doing
# few | couple, many, several, two, moments
# does | doesn, did, do, job, makes
# nothing | anything, something, everything, else, do
# trip | road, vacation, visit, journey, take
# disturbing | shocking, brutal, gruesome, scary, unsettling
# hair | blond, makeup, wearing, wig, red
# adventure | action, adventures, fantasy, western, excitement
# band | singer, rock, group, inxs, soundtrack
# changed | change, changes, different, forever, radically
# heavy | handed, metal, used, over, fair
# ultimately | sometimes, ending, somewhat, end, love
# ...
#
#  epoch 5[==........]time remaining (m) = 13.97 Avg Train_Loss=3.40166278Epoch: 5/15
# Loss:  3.4633870124816895
# now | then, years, since, been, ago
# do | don, did, does, make, doing
# off | into, away, down, while, then
# most | many, worst, ever, probably, lot
# director | writer, directed, directors, producer, screenplay
# also | great, though, both, role, played
# funny | hilarious, comedy, humor, amusing, jokes
# same | similar, different, exactly, both, another
# disturbing | shocking, brutal, unsettling, nudity, scary
# zombies | zombie, revolt, vampires, flesh, people
# german | french, english, american, russian, british
# considered | consider, certainly, possibly, because, gentlemen
# former | ex, played, later, new, named
# visual | effects, photography, cinematic, style, cinematography
# speak | language, accent, understand, word, english
# effective | performances, excellent, surprisingly, technically, memorable
# ...
#
#  epoch 5[===.......]time remaining (m) = 11.94 Avg Train_Loss=3.41140639Epoch: 5/15
# Loss:  3.4885764122009277
# any | anything, much, without, every, certainly
# acting | directing, performances, actors, direction, performance
# should | could, been, must, will, shouldn
# never | before, ever, ve, once, again
# most | ever, worst, many, best, probably
# actually | also, fact, thing, however, much
# through | sit, along, around, down, into
# such | many, other, most, made, these
# bored | boring, sat, disappointed, scared, dull
# showed | showing, shown, looked, shows, gave
# weren | wasn, aren, didn, been, knew
# effective | powerful, excellent, performances, creepy, memorable
# disturbing | shocking, brutal, nudity, unsettling, scary
# force | air, squad, forces, power, military
# moves | move, pace, goes, moved, fast
# project | witch, blair, competent, director, budget
# ...
#
#  epoch 5[====......]time remaining (m) = 9.95 Avg Train_Loss=3.41965328Epoch: 5/15
# Loss:  3.4008965492248535
# though | although, also, while, because, pretty
# show | shows, series, episode, tv, television
# being | having, getting, been, fact, gets
# should | could, been, must, will, maybe
# re | m, aren, isn, am, unless
# way | think, also, much, through, along
# watching | seeing, watch, watched, saw, viewing
# don | do, didn, want, know, doesn
# slasher | horror, slashers, flick, gore, genre
# former | ex, played, later, plays, group
# situations | situation, stressful, reactions, characters, scenarios
# hair | blond, makeup, red, wig, wearing
# starring | directed, plays, stars, starred, played
# control | power, domination, against, freedom, constant
# adventure | action, adventures, fantasy, western, poseidon
# died | death, dying, cancer, killed, shortly
# ...
#
#  epoch 5[=====.....]time remaining (m) = 7.97 Avg Train_Loss=3.42703291Epoch: 5/15
# Loss:  3.3973374366760254
# way | much, also, think, thing, through
# off | into, down, around, away, then
# make | makes, made, making, get, do
# because | though, why, didn, reason, people
# nothing | anything, something, else, everything, do
# should | could, been, must, better, will
# scenes | scene, sequences, moments, shots, parts
# made | makes, make, making, films, done
# project | witch, budget, production, blair, competent
# heavy | handed, metal, light, persian, deep
# kills | killing, kill, killed, accidentally, shoots
# dancing | dance, singing, astaire, ballroom, dances
# depth | emotion, development, characters, personality, dialogue
# makers | filmmakers, writers, directors, director, budget
# violent | violence, gory, brutal, sexual, yet
# value | entertainment, values, quality, redeeming, shonky
# ...
#
#  epoch 5[======....]time remaining (m) = 5.98 Avg Train_Loss=3.43392124Epoch: 5/15
# Loss:  3.487527370452881
# ever | worst, ve, seen, never, most
# now | then, again, years, know, think
# your | want, yourself, our, watch, waste
# actually | also, fact, however, thing, quite
# scene | scenes, sequence, where, moment, shot
# still | while, its, though, today, also
# back | then, home, into, where, again
# little | bit, much, also, nice, boy
# bizarre | strange, surreal, ending, erotic, creepy
# control | power, domination, freedom, against, constant
# college | students, school, student, university, class
# super | superhero, hero, ex, powers, mario
# fit | fits, seem, put, mulva, although
# situations | situation, stressful, reactions, scenarios, characters
# project | witch, blair, budget, competent, production
# effective | excellent, impressive, effectively, creepy, haunting
# ...
#
#  epoch 5[=======...]time remaining (m) = 4.0 Avg Train_Loss=3.44044561Epoch: 5/15
# Loss:  3.395353078842163
# doesn | does, didn, don, makes, did
# should | could, must, been, will, better
# people | these, them, don, women, because
# much | better, lot, far, little, too
# best | worst, great, greatest, most, performance
# will | ll, may, don, won, did
# look | looks, looking, looked, seem, makes
# where | scene, during, into, place, then
# common | denominator, sense, characters, helplessness, lowest
# conclusion | ending, end, climax, finale, ultimately
# singing | dancing, voice, songs, sing, sings
# law | jude, enforcement, father, police, daughter
# starring | directed, plays, stars, starred, version
# mad | scientist, crazy, monk, magician, dr
# solid | excellent, performances, fine, great, performance
# weren | wasn, aren, been, knew, these
# ...
#
#  epoch 5[========..]time remaining (m) = 2.02 Avg Train_Loss=3.44618735Epoch: 5/15
# Loss:  3.49627685546875
# while | though, after, still, then, however
# didn | did, doesn, don, wasn, know
# first | second, last, after, then, since
# should | could, must, been, maybe, might
# then | now, back, after, him, into
# how | why, people, know, where, think
# seen | ve, ever, watched, worst, heard
# why | reason, how, did, because, know
# sick | disgusting, twisted, crap, kisses, sure
# walk | walking, walks, walked, go, running
# impressive | excellent, great, features, interesting, convincing
# steve | mcqueen, carell, martin, buscemi, biko
# concept | idea, premise, ideas, potential, original
# ghost | ghosts, haunted, house, mysterious, spirit
# visual | effects, photography, cinematography, lighting, cinematic
# awesome | great, cool, terrific, excellent, fantastic
# ...
#
#  epoch 5[=========.]time remaining (m) = 0.05 Avg Train_Loss=3.4518912Epoch: 5/15
# Loss:  3.4871816635131836
# did | didn, does, do, why, don
# few | couple, many, several, two, those
# years | ago, year, days, later, times
# plot | storyline, script, characters, dialogue, acting
# do | don, does, did, know, make
# being | been, fact, getting, having, gets
# many | several, few, most, other, those
# could | couldn, might, should, been, better
# adult | children, adults, childhood, sexual, parent
# planet | earth, apes, alien, space, altair
# pointless | boring, unnecessary, stupid, lame, terrible
# solid | excellent, performances, fine, great, decent
# books | book, novels, read, novel, author
# speak | language, accent, english, understand, subtitles
# project | witch, blair, budget, competent, director
# bizarre | strange, surreal, weird, creepy, disturbing
# ...
#
#  training epoch 5 time Taken (m) = 19.75 Avg Train_Loss=3.45203999
#  epoch 5 train_loss =3.45203999  total_time= 19.75
# new minimum train loss 3.45203999  achieved, model weights saved
#  epoch 6[..........]time remaining (m) = 18.42 Avg Train_Loss=3.37053913Epoch: 6/15
# Loss:  3.39677095413208
# bad | awful, terrible, poor, stupid, acting
# where | scene, into, then, during, place
# scenes | scene, sequences, moments, shots, parts
# many | several, few, other, those, most
# people | women, them, these, americans, characters
# such | other, many, these, most, how
# them | him, these, other, people, themselves
# actually | also, though, thing, quite, bad
# dancing | dance, singing, ballroom, dances, song
# common | denominator, sense, do, science, major
# amusing | funny, entertaining, hilarious, enjoyable, moments
# amount | amounts, lot, contains, nudity, sufficient
# ultimately | its, conclusion, attempt, somewhat, pretentious
# laughing | laugh, loud, laughed, watching, laughter
# chemistry | between, presence, together, relationship, leads
# bizarre | strange, surreal, weird, disturbing, absurd
# ...
#
#  epoch 6[=.........]time remaining (m) = 16.11 Avg Train_Loss=3.38361633Epoch: 6/15
# Loss:  3.362738609313965
# another | yet, every, first, after, then
# acting | performances, directing, direction, actors, performance
# little | bit, much, too, nothing, also
# few | couple, many, several, two, these
# old | year, now, young, boy, plays
# doesn | does, didn, don, wants, did
# do | don, did, does, make, know
# nothing | anything, something, everything, else, absolutely
# awesome | great, cool, terrific, excellent, fantastic
# recommended | highly, recommend, sette, fans, am
# german | french, american, english, british, russian
# trash | garbage, piece, crap, exploitation, dreck
# positive | negative, reviews, comments, comment, here
# culture | society, pop, history, american, americans
# mad | scientist, crazy, accident, magician, lugosi
# trouble | getting, problem, help, going, himself
# ...
#
#  epoch 6[==........]time remaining (m) = 14.0 Avg Train_Loss=3.3946384Epoch: 6/15
# Loss:  3.3503715991973877
# new | york, city, orleans, different, now
# watch | watching, watched, rent, enjoy, want
# funny | hilarious, amusing, comedy, jokes, scary
# plot | storyline, script, characters, dialogue, ending
# movies | films, flicks, seen, comedies, horror
# made | makes, make, making, seen, done
# ve | seen, ever, haven, been, worst
# such | many, other, these, could, made
# former | ex, young, plays, friend, john
# heavy | handed, metal, style, dark, light
# slasher | horror, slashers, gore, genre, flick
# awesome | great, cool, fantastic, superb, terrific
# credit | deserves, writers, kudos, respect, give
# amount | amounts, contains, lot, nudity, sufficient
# kills | killing, kill, killed, killer, dies
# consider | think, considered, am, ask, call
# ...
#
#  epoch 6[===.......]time remaining (m) = 11.98 Avg Train_Loss=3.40362348Epoch: 6/15
# Loss:  3.446411609649658
# those | these, them, many, people, other
# ve | seen, ever, haven, been, worst
# through | around, into, back, sit, down
# being | been, having, fact, getting, gets
# way | think, much, also, how, other
# re | m, aren, am, unless, isn
# doesn | does, didn, don, wants, did
# scenes | scene, sequences, moments, shots, parts
# tony | plays, soprano, frank, leung, boss
# choice | casting, choices, could, decision, attempt
# german | french, american, english, british, wwii
# century | th, twentieth, st, period, england
# project | blair, witch, competent, documentary, collora
# animated | animation, disney, cartoon, cartoons, batman
# cover | box, jacket, trailer, dvd, video
# van | damme, sant, dyke, helsing, gus
# ...
#
#  epoch 6[====......]time remaining (m) = 9.98 Avg Train_Loss=3.41154516Epoch: 6/15
# Loss:  3.4995198249816895
# those | these, many, other, people, them
# seen | ve, ever, heard, worst, watched
# made | makes, make, making, seen, ve
# find | found, get, finds, watch, go
# other | each, these, them, many, others
# movies | films, flicks, seen, comedies, horror
# old | year, older, young, later, last
# thing | whole, things, though, bad, ever
# force | air, de, forces, tour, army
# portrayal | performance, played, role, portrayed, portrays
# project | witch, blair, computer, competent, collora
# focus | focuses, focused, tension, central, character
# producers | writers, director, filmmakers, did, directors
# situations | situation, stressful, scenarios, reactions, characters
# exciting | interesting, enjoyable, thrilling, entertaining, tense
# amusing | funny, entertaining, hilarious, enjoyable, moments
# ...
#
#  epoch 6[=====.....]time remaining (m) = 7.98 Avg Train_Loss=3.41920104Epoch: 6/15
# Loss:  3.4203224182128906
# end | ending, beginning, final, towards, last
# great | excellent, wonderful, fine, best, also
# over | top, then, again, once, around
# m | am, sure, re, wasn, say
# way | also, think, through, much, other
# new | york, city, orleans, same, now
# him | them, himself, father, guy, man
# actually | also, thing, however, fact, bad
# tone | franchot, atmosphere, mood, pace, perfectly
# tony | soprano, plays, imperioli, scott, leung
# italian | french, european, spanish, italy, american
# runs | gets, run, running, goes, turns
# speak | language, accent, english, speaking, subtitles
# project | witch, blair, competent, computer, budget
# force | air, de, tour, redemption, forces
# law | jude, enforcement, enforcing, father, police
# ...
#
#  epoch 6[======....]time remaining (m) = 6.0 Avg Train_Loss=3.42599618Epoch: 6/15
# Loss:  3.486818313598633
# make | makes, made, making, do, get
# don | do, didn, know, want, doesn
# seen | ve, heard, ever, watched, worst
# still | while, its, years, today, yet
# over | top, then, again, once, around
# director | writer, directed, producer, directors, screenplay
# thing | whole, things, moment, bad, think
# movies | films, flicks, comedies, horror, seen
# dancing | dance, singing, ballroom, astaire, dances
# steve | carell, mcqueen, martin, buscemi, biko
# culture | society, pop, american, cultural, western
# recommended | highly, recommend, sette, expect, fans
# trip | road, vacation, camping, journey, canoe
# trash | garbage, piece, crap, junk, exploitation
# basic | instinct, premise, plot, basically, stupid
# speak | language, accent, english, speaking, mostly
# ...
#
#  epoch 6[=======...]time remaining (m) = 4.02 Avg Train_Loss=3.43265911Epoch: 6/15
# Loss:  3.538529872894287
# seen | ve, ever, watched, heard, worst
# much | better, lot, anything, far, little
# new | york, city, orleans, now, old
# while | after, though, then, still, however
# will | ll, may, don, won, must
# m | am, sure, re, wasn, im
# should | could, been, must, shouldn, will
# little | bit, much, boy, lot, nice
# college | school, students, student, university, high
# language | english, subtitles, speak, foul, violence
# changed | change, changes, radically, forever, different
# amusing | funny, entertaining, hilarious, interesting, enjoyable
# tone | franchot, atmosphere, mood, style, harlow
# makers | filmmakers, writers, director, directors, budget
# prison | jail, warden, prisoners, police, cell
# violent | violence, brutal, gory, graphic, sexual
# ...
#
#  epoch 6[========..]time remaining (m) = 2.04 Avg Train_Loss=3.43828325Epoch: 6/15
# Loss:  3.5133798122406006
# before | after, never, since, until, first
# part | role, parts, roles, played, plays
# another | every, yet, also, first, called
# watching | seeing, watch, watched, saw, worth
# go | went, goes, get, going, do
# been | could, ve, done, should, seen
# where | scene, how, during, place, back
# him | them, himself, father, man, wife
# tony | soprano, leung, frank, himself, danny
# portrayal | performance, role, played, portrays, plays
# adult | children, adults, childhood, parent, sexual
# company | studio, soon, new, corporation, industry
# successful | popular, talented, interested, career, success
# pointless | unnecessary, boring, lame, stupid, annoying
# heavy | handed, metal, style, starts, often
# ultimately | interesting, ending, sometimes, conclusion, its
# ...
#
#  epoch 6[=========.]time remaining (m) = 0.06 Avg Train_Loss=3.44375013Epoch: 6/15
# Loss:  3.5382964611053467
# man | woman, guy, men, him, himself
# say | think, know, watch, said, seen
# bad | awful, terrible, acting, horrible, poor
# while | after, though, then, still, however
# after | before, while, then, first, later
# same | similar, both, different, type, also
# why | how, reason, because, did, understand
# great | excellent, wonderful, fine, fantastic, also
# ultimately | end, its, rather, ending, conclusion
# smith | joseph, perry, pinkett, maggie, scott
# situations | situation, stressful, scenarios, reactions, characters
# showed | shows, shown, looked, showing, liked
# steve | carell, mcqueen, martin, buscemi, biko
# consider | considered, think, ask, seen, found
# moves | goes, moved, move, takes, quickly
# sick | disgusting, twisted, depressed, gory, crap
# ...
#
#  training epoch 6 time Taken (m) = 19.83 Avg Train_Loss=3.44390968
#  epoch 6 train_loss =3.44390968  total_time= 19.83
# new minimum train loss 3.44390968  achieved, model weights saved
#  epoch 7[..........]time remaining (m) = 18.5 Avg Train_Loss=3.36598107Epoch: 7/15
# Loss:  3.3630239963531494
# over | top, again, then, once, off
# love | romance, fall, relationship, great, beautiful
# didn | did, doesn, don, wasn, couldn
# through | down, into, around, sit, back
# after | before, while, then, first, later
# back | then, down, home, where, away
# then | back, after, once, into, now
# make | made, makes, making, get, do
# adult | children, adults, sexual, oriented, childhood
# runs | run, gets, goes, running, car
# successful | popular, career, talented, brilliant, success
# smith | joseph, perry, pinkett, scott, maggie
# ghost | ghosts, haunted, house, spirit, traditional
# project | blair, witch, computer, budget, effort
# super | superhero, mario, hyperactive, computer, ex
# italian | french, spanish, european, irish, italy
# ...
#
#  epoch 7[=.........]time remaining (m) = 16.1 Avg Train_Loss=3.37717437Epoch: 7/15
# Loss:  3.328974962234497
# did | didn, does, do, why, don
# should | could, been, must, shouldn, might
# get | gets, getting, got, go, make
# into | then, off, down, back, through
# still | today, while, years, now, quite
# scene | scenes, where, sequence, moment, moments
# been | done, should, could, ve, seen
# nothing | anything, something, else, everything, do
# showed | shows, looked, shown, showing, gave
# trouble | getting, problem, problems, himself, help
# moves | moved, pace, move, starts, takes
# runs | gets, run, goes, running, car
# considered | consider, possibly, certainly, because, say
# makers | filmmakers, writers, directors, director, budget
# situations | situation, stressful, scenarios, reactions, characters
# german | french, american, english, russian, british
# ...
#
#  epoch 7[==........]time remaining (m) = 14.35 Avg Train_Loss=3.38566296

# %%
saving_path="/content/drive/MyDrive"

full_path = '/content/drive/MyDrive/projects/sentiment-analysis-RNN/model_weights/skipgram/train_loss_4.21.pt'
torch.save(model.state_dict(), full_path)
